# %%
Generated entirely by claude - iteratively to check

# %% [markdown]
# # Condensed QA-flag summary figures (per-flag, not composited)
#
# This notebook reduces the per-pixel-day QA flags (dims: scenario x ensemble member x
# variable x day x lat x lon) down to a manageable set of maps, time series, and tables --
# one flag at a time, never OR'd together into a composite.
#
# It reads from the **intermediate per-tag flag stores** written by
# `flag_step2_generate-intermediate-qa-flags.ipynb`
# (`get_intermediate_flags`, one icechunk repo per `{gcm}_{var}_{scenario}_{ens}_{method}` tag),
# *not* the final combined store written by `flag_step3_combine_and_write_to_source_coop.ipynb` --
# that final store only contains the two OR'd composite flags
# (`qa_flag_time_varying` / `qa_flag_time_invariant`), which is exactly what we don't want here.
#
# ## Design: compute once, cache to CACHE_DIR, plot from the cache
#
# Every analysis cell below is split into two phases:
#
# 1. **Compute** cells that touch the raw flag arrays via dask, reduce them down to small
#    maps/time-series/tables, and cache each result to `CACHE_DIR` as soon as it's computed.
#    `CACHE_DIR` is an `s3://` prefix, not local disk -- the per-combo pickles add up to
#    roughly 10GB (see the Hovmoller section below for why), too much to write locally on a
#    temporary/small-disk remote machine.
# 2. **Plot** cells (bottom half of the notebook) that only ever read from the small cached
#    results in memory. They never re-touch dask or icechunk.
#
# So if you come back later to change a label, colormap, or colorbar, you only need to
# re-run the plotting cells -- and if you restart the kernel entirely, re-running the
# compute cells from the top is cheap too, since `compute_or_load` skips any combo that's
# already cached in `CACHE_DIR` and just unpickles it.
#
# Before committing to the full run (every flag x variable x scenario, the expensive part),
# there's a **Quick preview** section that computes and plots just one flag/variable so you
# can confirm the analysis is heading the direction you want. Nothing it computes is
# wasted: it's cached the same way as everything else, so the full run's compute loop just
# reloads it instead of recomputing.
#
# ## Chunk-size-informed scope
#
# Flags are stored `uint8` on a global 0.25 deg grid (720 lat x 1440 lon), chunked
# `(365 time, 36 lat, 72 lon)` / sharded `(1095 time, 180 lat, 360 lon)`. Reductions over a
# whole axis (time, space, or lon-only) are cheap, chunk-aligned tree-reductions -- that
# covers every figure below. The one thing we're intentionally *not* computing here is a
# longest-consecutive-flagged-run ("persistence") map: that needs an ordered scan along
# time rather than a plain reduction, and it's ambiguous across the historical / ssp245 /
# g6_1p5k / g6_1p5k_end scenario breaks anyway. Worth doing later, targeted, only on
# specific flag/variable/scenario cells that these figures flag as suspicious.

# %%
import pickle
from concurrent.futures import ThreadPoolExecutor, as_completed
from pathlib import Path

import cartopy.crs as ccrs
import cartopy.feature as cfeature
import dask
import fsspec
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import rusterize as _rusterize_pkg
import xarray as xr
from dask.distributed import Client, LocalCluster
from matplotlib.colors import ListedColormap
from rasterix.rasterize import geometry_mask
from tqdm.auto import tqdm

from srm import catalog
from srm.qa_flags import (
    FLAG_LIST_TIME_INVARIANT,
    FLAG_LIST_TIME_VARYING,
    INPUT_CHUNKS,
    discover_leaves,
    get_intermediate_flags,
    parse_tag,
)

# %%
# --- Run parameters ---------------------------------------------------------
# Must match the run that produced the intermediate per-tag flag stores -- see
# flag_step2_generate-intermediate-qa-flags.ipynb for the same values.
GCMS = ["CESM2-WACCM"]
VARIABLES = ["tas", "tasmax", "tasmin", "pr", "rsds"]

BRANCH = "pr-638-global"  # branch of the raw/debiased data trees, used only to discover tags
ROOT_DIR = "s3://carbonplan-srm/scratch/output/qa/"
STORE_SUBSET_ID = "global"

FLAG_BUCKET = "carbonplan-srm"
FLAG_PREFIX = "scratch/output/qa-intermediate-flags"  # where get_intermediate_flags reads from

SCENARIO_ORDER = ["historical", "ssp245", "g6_1p5k", "g6_1p5k_end"]

CACHE_DIR = "s3://carbonplan-srm/scratch/intermediate_qa_flag"  # per-combo compute results (pkl -- large)

FIGURE_DIR = Path("./qa_condensed_figures")  # saved PNGs of every figure this notebook makes
FIGURE_DIR.mkdir(exist_ok=True)

N_IO_THREADS = 32  # concurrent "open icechunk store" calls -- separate from dask's own parallelism

# Local distributed cluster, sized for one 64-cpu / 250GB machine -- see the markdown note
# just above the cluster-startup cell below for why this replaced a plain scheduler="threads"
# config. Tune DASK_N_WORKERS x DASK_MEMORY_LIMIT_PER_WORKER to stay comfortably under your
# machine's actual RAM (defaults below: 8 x 24GB = 192GB, leaving ~58GB of headroom).
DASK_N_WORKERS = 8
DASK_THREADS_PER_WORKER = 8
DASK_MEMORY_LIMIT_PER_WORKER = "24GB"

# %% [markdown]
# ## Dask cluster
#
# **If Compute pass 1 previously died with a memory error, this cell is the fix.** The plain
# `dask.config.set(scheduler="threads")` this notebook used to set up here has no memory
# awareness: it greedily starts every ready task as soon as a thread is free, with no regard
# for how much intermediate (chunk-read, decompressed, not-yet-reduced) data is sitting in
# RAM. On a wide reduction graph -- and `historical` alone is ~60,225 days, i.e. up to
# ~66,000 zarr chunks per ensemble member at the on-disk `(365, 36, 72)` chunk size -- that
# scheduler can end up holding far more decompressed chunks in flight at once than the
# reduction actually needs, with no back-pressure and nowhere to spill. That's almost
# certainly what ran the machine out of memory.
#
# A local `distributed` cluster fixes both halves of this:
# - its scheduler is memory-aware and prioritizes finishing in-progress reduction branches
#   over greedily starting new ones, so peak memory stays bounded near the workers' limits
#   instead of growing with graph width;
# - each worker gets a hard `memory_limit` and spills to disk automatically as it approaches
#   it, so a bad combo degrades (slower) instead of crashing the kernel.
#
# The `_open_flags` cell below also now explicitly rechunks every flag array to
# `INPUT_CHUNKS` (the same shard-aligned `(1095, 180, 360)` chunking `discover_leaves`
# already uses for the raw data trees) right after opening it, instead of relying on
# `xr.open_zarr`'s default chunk selection -- that bounds each chunk at a known, sane size
# and cuts the historical-scenario graph from ~66,000 chunks/member down to ~880.

# %%
cluster = LocalCluster(
    n_workers=DASK_N_WORKERS,
    threads_per_worker=DASK_THREADS_PER_WORKER,
    memory_limit=DASK_MEMORY_LIMIT_PER_WORKER,
)
client = Client(cluster)
client
# Out:
# <Client: 'tcp://127.0.0.1:41121' processes=8 threads=64, memory=178.81 GiB>
# 2026-08-28 22:40:40,424 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle fbe3ddab7c172bdca17947f0d835ba19 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 2, 4, 3, 3, 8, 15) executed on worker tcp://127.0.0.1:41177
# 2026-08-28 22:40:40,426 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle cccdb2190e1cd409e3c5329a614730bc initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 4, 2, 3, 6, 5, 17) executed on worker tcp://127.0.0.1:41177
# 2026-08-28 22:40:40,445 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 393833f64dc0db01abfbfd6371c6f450 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 4, 4, 3, 6, 8, 15) executed on worker tcp://127.0.0.1:41177
# 2026-08-28 22:40:40,446 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle f02d5c34576361f0678b1eb3fe87714b initialized by task ('rechunk-merge-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 4, 3, 3, 6, 6, 17) executed on worker tcp://127.0.0.1:41177
# 2026-08-28 22:40:40,450 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle f4faf6a23b06e15033b81c06dc279019 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 2, 3, 3, 3, 7, 15) executed on worker tcp://127.0.0.1:41177
# 2026-08-28 22:40:40,492 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle c6ba6bb89081b0267b7dfb2f17faa3cc initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 0, 3, 2, 0, 7, 9) executed on worker tcp://127.0.0.1:39791
# 2026-08-28 22:40:40,493 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle a613d3465c06f6c5dd96b65bcdc4547d initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 2, 2, 3, 3, 5, 16) executed on worker tcp://127.0.0.1:41177
# 2026-08-28 22:40:40,497 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle d6840c172eddb8957a432b2d74d1b9d4 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 0, 4, 2, 0, 8, 9) executed on worker tcp://127.0.0.1:39791
# 2026-08-28 22:40:40,498 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 2394b4aba2cebaf75b29d74395afcb00 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 4, 2, 2, 6, 5, 10) executed on worker tcp://127.0.0.1:36099
# 2026-08-28 22:40:40,501 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 95ba93dfb94397dd27ae85b82caffd17 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 4, 3, 2, 6, 7, 11) executed on worker tcp://127.0.0.1:41309
# 2026-08-28 22:40:40,503 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 2e7db95e6e1efeb616b1ac95036233d0 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 0, 4, 1, 0, 8, 8) executed on worker tcp://127.0.0.1:39791
# 2026-08-28 22:40:40,509 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 418ea42721c545784fd7905c7e6c38d4 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 2, 3, 2, 3, 7, 9) executed on worker tcp://127.0.0.1:41309
# 2026-08-28 22:40:40,509 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle a945c2d24a4b2908fe3e6a363f7be4ad initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 4, 4, 2, 6, 8, 11) executed on worker tcp://127.0.0.1:41309
# 2026-08-28 22:40:40,510 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 489900f1b9221a782789755c8e7f5fb0 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 2, 4, 2, 3, 8, 9) executed on worker tcp://127.0.0.1:41309
# 2026-08-28 22:40:40,511 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 4e68543b01daaf52d0f4b478841fe8c5 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 0, 3, 3, 0, 7, 15) executed on worker tcp://127.0.0.1:39479
# 2026-08-28 22:40:40,516 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 7c4d723ee6dffb2373f98f9ea9f7995c initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 0, 4, 3, 0, 8, 15) executed on worker tcp://127.0.0.1:39479
# 2026-08-28 22:40:40,640 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 336433488d3e743bf46b29290d7b6b43 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 4, 1, 3, 6, 3, 16) executed on worker tcp://127.0.0.1:41177
# 2026-08-28 22:40:40,669 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 27af82ec4212f43b9878aa4e43eb91e8 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 0, 2, 2, 0, 5, 11) executed on worker tcp://127.0.0.1:39791
# 2026-08-28 22:40:40,676 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 1534f75a876e920a99714e9c603ca97f initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 0, 3, 1, 0, 7, 8) executed on worker tcp://127.0.0.1:39791
# 2026-08-28 22:40:40,678 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle de7130ff86b6d3590fa1da3d0df1d344 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 0, 2, 3, 0, 5, 17) executed on worker tcp://127.0.0.1:44797
# 2026-08-28 22:40:40,701 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle e25e3afa5c8a6fd0a9e75d7d01be816f initialized by task ('rechunk-merge-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 4, 3, 1, 6, 6, 8) executed on worker tcp://127.0.0.1:36099
# 2026-08-28 22:40:40,702 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle cc35c85b04953cbb86f4552abdf8fb04 initialized by task ('rechunk-merge-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 2, 3, 1, 3, 6, 8) executed on worker tcp://127.0.0.1:41309
# 2026-08-28 22:40:40,726 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 3f7e777628066d66a314481f22375783 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 2, 2, 2, 3, 5, 10) executed on worker tcp://127.0.0.1:36099
# 2026-08-28 22:40:40,745 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 9fb5e1cde51fe007fa74fdc5edc24021 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 0, 2, 1, 0, 5, 8) executed on worker tcp://127.0.0.1:39791
# 2026-08-28 22:40:40,806 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle b0b16af1da1e52b793efcf1b913e3db2 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 4, 4, 1, 6, 8, 8) executed on worker tcp://127.0.0.1:41309
# 2026-08-28 22:40:40,813 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle f7461e2cc6e95e996c800586cd8b9c73 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 2, 1, 3, 3, 3, 17) executed on worker tcp://127.0.0.1:41177
# 2026-08-28 22:40:40,823 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 41525e81d8dbed3a90cf804759231567 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 2, 4, 1, 3, 8, 8) executed on worker tcp://127.0.0.1:41309
# 2026-08-28 22:40:40,837 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle b8d4eed180bec0880f082e60bd4aad5b initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 4, 2, 1, 6, 5, 8) executed on worker tcp://127.0.0.1:36099
# 2026-08-28 22:40:40,896 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle e5ed3877d372a4cce90769d2e69f19d0 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 2, 2, 1, 3, 5, 8) executed on worker tcp://127.0.0.1:41309
# 2026-08-28 22:40:41,000 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 68799bf8ce9f445e7e789bf2e4b4a804 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 4, 1, 2, 6, 3, 12) executed on worker tcp://127.0.0.1:42581
# 2026-08-28 22:40:41,003 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle ca9495f617cc183ffac3809cb8d9ef0c initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 2, 1, 2, 3, 3, 12) executed on worker tcp://127.0.0.1:42581
# 2026-08-28 22:40:41,071 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 4a1bb022bc1a05df7f0165d8e482fc33 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 0, 1, 3, 0, 3, 17) executed on worker tcp://127.0.0.1:39791
# 2026-08-28 22:40:41,131 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 393833f64dc0db01abfbfd6371c6f450 deactivated due to stimulus 'task-finished-1787956841.0999565'
# 2026-08-28 22:40:41,266 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 4c591bdfd8da7e1f60cda1b3813fe5bd initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 0, 1, 2, 0, 3, 10) executed on worker tcp://127.0.0.1:42581
# 2026-08-28 22:40:41,267 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 4fbe411baa73bfa7a935837ee6bd68f5 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 2, 1, 1, 3, 3, 8) executed on worker tcp://127.0.0.1:42581
# 2026-08-28 22:40:41,296 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 7c4d723ee6dffb2373f98f9ea9f7995c deactivated due to stimulus 'task-finished-1787956841.2691278'
# 2026-08-28 22:40:41,379 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle a945c2d24a4b2908fe3e6a363f7be4ad deactivated due to stimulus 'task-finished-1787956841.3675687'
# 2026-08-28 22:40:41,434 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle fbe3ddab7c172bdca17947f0d835ba19 deactivated due to stimulus 'task-finished-1787956841.4077523'
# 2026-08-28 22:40:41,443 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 4a4ef963ee8b43ab49d1fbae959a525a initialized by task ('rechunk-merge-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 2, 3, 0, 3, 6, 3) executed on worker tcp://127.0.0.1:40095
# 2026-08-28 22:40:41,450 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle f02d5c34576361f0678b1eb3fe87714b deactivated due to stimulus 'task-finished-1787956841.4501147'
# 2026-08-28 22:40:41,505 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle cccdb2190e1cd409e3c5329a614730bc deactivated due to stimulus 'task-finished-1787956841.4949007'
# 2026-08-28 22:40:41,555 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 418ea42721c545784fd7905c7e6c38d4 deactivated due to stimulus 'task-finished-1787956841.5419178'
# 2026-08-28 22:40:41,575 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 927d76bc1eaea5e6bfb3e022cae6d225 initialized by task ('rechunk-merge-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 4, 3, 0, 6, 6, 3) executed on worker tcp://127.0.0.1:40095
# 2026-08-28 22:40:41,588 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle d6840c172eddb8957a432b2d74d1b9d4 deactivated due to stimulus 'task-finished-1787956841.5869157'
# 2026-08-28 22:40:41,590 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 19f05bdd8b1adb062ba351e1b976a8bc initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 0, 1, 1, 0, 3, 8) executed on worker tcp://127.0.0.1:42581
# 2026-08-28 22:40:41,625 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 489900f1b9221a782789755c8e7f5fb0 deactivated due to stimulus 'task-finished-1787956841.5840302'
# 2026-08-28 22:40:41,723 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 95ba93dfb94397dd27ae85b82caffd17 deactivated due to stimulus 'task-finished-1787956841.7221065'
# 2026-08-28 22:40:41,798 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 4e68543b01daaf52d0f4b478841fe8c5 deactivated due to stimulus 'task-finished-1787956841.7946453'
# 2026-08-28 22:40:41,840 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle f4faf6a23b06e15033b81c06dc279019 deactivated due to stimulus 'task-finished-1787956841.8086898'
# 2026-08-28 22:40:41,842 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle c6ba6bb89081b0267b7dfb2f17faa3cc deactivated due to stimulus 'task-finished-1787956841.8119838'
# 2026-08-28 22:40:41,859 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle a613d3465c06f6c5dd96b65bcdc4547d deactivated due to stimulus 'task-finished-1787956841.8291605'
# 2026-08-28 22:40:41,893 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 2720c593eb3c3979962c389c7738c453 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 4, 2, 0, 6, 5, 3) executed on worker tcp://127.0.0.1:40095
# 2026-08-28 22:40:41,926 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle d42579f2081cbd85d0c88680bdb4581b initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 2, 2, 0, 3, 5, 3) executed on worker tcp://127.0.0.1:40095
# 2026-08-28 22:40:42,112 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 2394b4aba2cebaf75b29d74395afcb00 deactivated due to stimulus 'task-finished-1787956842.10958'
# 2026-08-28 22:40:42,182 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle de7130ff86b6d3590fa1da3d0df1d344 deactivated due to stimulus 'task-finished-1787956842.1420293'
# 2026-08-28 22:40:42,201 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 3f7e777628066d66a314481f22375783 deactivated due to stimulus 'task-finished-1787956842.187593'
# 2026-08-28 22:40:42,280 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle b0b16af1da1e52b793efcf1b913e3db2 deactivated due to stimulus 'task-finished-1787956842.2731957'
# 2026-08-28 22:40:42,358 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 4cf31229bc2d8b9fef84ecb0a8ac6ca9 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 4, 4, 0, 6, 8, 3) executed on worker tcp://127.0.0.1:42581
# 2026-08-28 22:40:42,408 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle efa0b1dcf21542ee72466125a5efcbfc initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 2, 4, 0, 3, 8, 3) executed on worker tcp://127.0.0.1:42581
# 2026-08-28 22:40:42,415 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle fe586dcc4776ff9f62fe2e584f67161b initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 4, 1, 1, 6, 3, 8) executed on worker tcp://127.0.0.1:41177
# 2026-08-28 22:40:42,447 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle e25e3afa5c8a6fd0a9e75d7d01be816f deactivated due to stimulus 'task-finished-1787956842.4271617'
# 2026-08-28 22:40:42,588 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 27af82ec4212f43b9878aa4e43eb91e8 deactivated due to stimulus 'task-finished-1787956842.5824482'
# 2026-08-28 22:40:42,629 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle cc35c85b04953cbb86f4552abdf8fb04 deactivated due to stimulus 'task-finished-1787956842.6283488'
# 2026-08-28 22:40:42,664 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 39c935d7e21e62c45b49289337ebb782 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 0, 3, 0, 0, 7, 3) executed on worker tcp://127.0.0.1:36099
# 2026-08-28 22:40:42,667 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 845619f41af6a610f1113d53f8f9e2fd initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 0, 4, 0, 0, 8, 3) executed on worker tcp://127.0.0.1:36099
# 2026-08-28 22:40:42,675 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 495408d398b7750fef649687f0acd5aa initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 0, 2, 0, 0, 5, 3) executed on worker tcp://127.0.0.1:39479
# 2026-08-28 22:40:42,702 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 41525e81d8dbed3a90cf804759231567 deactivated due to stimulus 'task-finished-1787956842.684183'
# 2026-08-28 22:40:42,719 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle a3b1d2e4ba99c76bb11254f1137a8066 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 4, 1, 0, 6, 3, 3) executed on worker tcp://127.0.0.1:40095
# 2026-08-28 22:40:42,783 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle d85b4ab0f2dbe9a8e3bbf7f76b62f3a3 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 2, 1, 0, 3, 3, 3) executed on worker tcp://127.0.0.1:41177
# 2026-08-28 22:40:42,965 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 2e7db95e6e1efeb616b1ac95036233d0 deactivated due to stimulus 'task-finished-1787956842.9431834'
# 2026-08-28 22:40:43,005 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle dc61f9666eb6d374ef13f6ce40ea225a initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 0, 1, 0, 0, 3, 3) executed on worker tcp://127.0.0.1:42581
# 2026-08-28 22:40:43,114 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 506c518e366c0352bd9b5b0c8484e11a initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 4, 0, 3, 6, 1, 16) executed on worker tcp://127.0.0.1:36099
# 2026-08-28 22:40:43,229 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle b8d7a0e199daf194e51b05c5683f2636 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 0, 0, 3, 0, 1, 17) executed on worker tcp://127.0.0.1:39791
# 2026-08-28 22:40:43,308 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 1534f75a876e920a99714e9c603ca97f deactivated due to stimulus 'task-finished-1787956843.2750506'
# 2026-08-28 22:40:43,310 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 7f29ab9f2f4fc4f6689a9df80c58691b initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 2, 0, 3, 3, 1, 13) executed on worker tcp://127.0.0.1:36099
# 2026-08-28 22:40:43,359 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 6e71d45e995e138394a5844d1fb11cf3 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 2, 0, 2, 3, 1, 12) executed on worker tcp://127.0.0.1:36099
# 2026-08-28 22:40:43,365 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 927d76bc1eaea5e6bfb3e022cae6d225 deactivated due to stimulus 'task-finished-1787956843.3466885'
# 2026-08-28 22:40:43,394 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 4cf31229bc2d8b9fef84ecb0a8ac6ca9 deactivated due to stimulus 'task-finished-1787956843.3789525'
# 2026-08-28 22:40:43,427 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle b8d4eed180bec0880f082e60bd4aad5b deactivated due to stimulus 'task-finished-1787956843.4169073'
# 2026-08-28 22:40:43,471 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle d2512936ff1fc98a4a4b710f74624d64 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 0, 0, 2, 0, 1, 12) executed on worker tcp://127.0.0.1:39791
# 2026-08-28 22:40:43,478 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle efa0b1dcf21542ee72466125a5efcbfc deactivated due to stimulus 'task-finished-1787956843.4568603'
# 2026-08-28 22:40:43,530 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 845619f41af6a610f1113d53f8f9e2fd deactivated due to stimulus 'task-finished-1787956843.489458'
# 2026-08-28 22:40:43,815 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 2720c593eb3c3979962c389c7738c453 deactivated due to stimulus 'task-finished-1787956843.7980092'
# 2026-08-28 22:40:43,825 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle e5ed3877d372a4cce90769d2e69f19d0 deactivated due to stimulus 'task-finished-1787956843.777032'
# 2026-08-28 22:40:43,873 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle c83431ad15ce3836c9cc1d23ed9b6c7a initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 4, 0, 2, 6, 1, 11) executed on worker tcp://127.0.0.1:44797
# 2026-08-28 22:40:43,896 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 9fb5e1cde51fe007fa74fdc5edc24021 deactivated due to stimulus 'task-finished-1787956843.8352172'
# 2026-08-28 22:40:43,914 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 4a4ef963ee8b43ab49d1fbae959a525a deactivated due to stimulus 'task-finished-1787956843.8754444'
# 2026-08-28 22:40:44,000 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle d42579f2081cbd85d0c88680bdb4581b deactivated due to stimulus 'task-finished-1787956843.9988663'
# 2026-08-28 22:40:44,148 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 39c935d7e21e62c45b49289337ebb782 deactivated due to stimulus 'task-finished-1787956844.1471033'
# 2026-08-28 22:40:44,331 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 336433488d3e743bf46b29290d7b6b43 deactivated due to stimulus 'task-finished-1787956844.3227303'
# 2026-08-28 22:40:44,341 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 4a1bb022bc1a05df7f0165d8e482fc33 deactivated due to stimulus 'task-finished-1787956844.3380435'
# 2026-08-28 22:40:44,434 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 495408d398b7750fef649687f0acd5aa deactivated due to stimulus 'task-finished-1787956844.3955019'
# 2026-08-28 22:40:44,486 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle f7461e2cc6e95e996c800586cd8b9c73 deactivated due to stimulus 'task-finished-1787956844.483045'
# 2026-08-28 22:40:44,632 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 8ec9aa96be8ad4a225dbfc3bee1051ef initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 4, 0, 1, 6, 1, 8) executed on worker tcp://127.0.0.1:42581
# 2026-08-28 22:40:44,671 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle d2a25b4bcdd06ab80b624804d47893b2 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 0, 0, 1, 0, 1, 8) executed on worker tcp://127.0.0.1:40095
# 2026-08-28 22:40:44,699 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 9c94898578b4da70b58497ef476c876d initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 2, 0, 1, 3, 1, 8) executed on worker tcp://127.0.0.1:39479
# 2026-08-28 22:40:44,967 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 990872bea14e80f6210a92f31469414f initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 2, 0, 0, 3, 1, 2) executed on worker tcp://127.0.0.1:41309
# 2026-08-28 22:40:44,975 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 731d438db94eebc149cbc8df3d9651ad initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 4, 0, 0, 6, 1, 3) executed on worker tcp://127.0.0.1:41177
# 2026-08-28 22:40:44,984 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 31e84317b3fc08d4771f36c1cd090145 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-61e50cf8e8a5106389b673b8902ca013', 0, 0, 0, 0, 1, 3) executed on worker tcp://127.0.0.1:44797
# 2026-08-28 22:40:45,098 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 68799bf8ce9f445e7e789bf2e4b4a804 deactivated due to stimulus 'task-finished-1787956845.07968'
# 2026-08-28 22:40:45,311 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 506c518e366c0352bd9b5b0c8484e11a deactivated due to stimulus 'task-finished-1787956845.2991433'
# 2026-08-28 22:40:45,479 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 4c591bdfd8da7e1f60cda1b3813fe5bd deactivated due to stimulus 'task-finished-1787956845.4212756'
# 2026-08-28 22:40:45,502 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle ca9495f617cc183ffac3809cb8d9ef0c deactivated due to stimulus 'task-finished-1787956845.4642656'
# 2026-08-28 22:40:45,511 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 7f29ab9f2f4fc4f6689a9df80c58691b deactivated due to stimulus 'task-finished-1787956845.4849124'
# 2026-08-28 22:40:45,705 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle c83431ad15ce3836c9cc1d23ed9b6c7a deactivated due to stimulus 'task-finished-1787956845.614923'
# 2026-08-28 22:40:45,706 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle b8d7a0e199daf194e51b05c5683f2636 deactivated due to stimulus 'task-finished-1787956845.6493585'
# 2026-08-28 22:40:45,751 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 6e71d45e995e138394a5844d1fb11cf3 deactivated due to stimulus 'task-finished-1787956845.6826005'
# 2026-08-28 22:40:45,872 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle d2512936ff1fc98a4a4b710f74624d64 deactivated due to stimulus 'task-finished-1787956845.8689315'
# 2026-08-28 22:40:46,013 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle a3b1d2e4ba99c76bb11254f1137a8066 deactivated due to stimulus 'task-finished-1787956846.0123115'
# 2026-08-28 22:40:46,065 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle d85b4ab0f2dbe9a8e3bbf7f76b62f3a3 deactivated due to stimulus 'task-finished-1787956846.0427709'
# 2026-08-28 22:40:46,177 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle fe586dcc4776ff9f62fe2e584f67161b deactivated due to stimulus 'task-finished-1787956846.1760547'
# 2026-08-28 22:40:46,189 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 4fbe411baa73bfa7a935837ee6bd68f5 deactivated due to stimulus 'task-finished-1787956846.1787415'
# 2026-08-28 22:40:46,196 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 19f05bdd8b1adb062ba351e1b976a8bc deactivated due to stimulus 'task-finished-1787956846.1824253'
# 2026-08-28 22:40:46,323 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle dc61f9666eb6d374ef13f6ce40ea225a deactivated due to stimulus 'task-finished-1787956846.3144422'
# 2026-08-28 22:40:46,413 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 8ec9aa96be8ad4a225dbfc3bee1051ef deactivated due to stimulus 'task-finished-1787956846.406567'
# 2026-08-28 22:40:46,520 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle d2a25b4bcdd06ab80b624804d47893b2 deactivated due to stimulus 'task-finished-1787956846.5151613'
# 2026-08-28 22:40:46,607 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 731d438db94eebc149cbc8df3d9651ad deactivated due to stimulus 'task-finished-1787956846.6036603'
# 2026-08-28 22:40:46,756 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 99efc8a0b119a9e5a92a6adc0b427ab7 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 4, 4, 3, 6, 8, 13) executed on worker tcp://127.0.0.1:44797
# 2026-08-28 22:40:46,758 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 135ae5f166a7d216ea036f06fb536e3a initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 4, 3, 3, 6, 7, 13) executed on worker tcp://127.0.0.1:44797
# 2026-08-28 22:40:46,784 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 9c94898578b4da70b58497ef476c876d deactivated due to stimulus 'task-finished-1787956846.7551327'
# 2026-08-28 22:40:46,791 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 4628d61fdc5d66035ca1984e693cb1b7 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 4, 3, 2, 6, 7, 12) executed on worker tcp://127.0.0.1:44797
# 2026-08-28 22:40:46,792 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 80f2408c88623bcb2bfa16d70dfffc38 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 4, 4, 2, 6, 8, 12) executed on worker tcp://127.0.0.1:44797
# 2026-08-28 22:40:46,840 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle e1bcec1b9382563e681942571ffb4893 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 4, 2, 3, 6, 5, 17) executed on worker tcp://127.0.0.1:44797
# 2026-08-28 22:40:46,843 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 990872bea14e80f6210a92f31469414f deactivated due to stimulus 'task-finished-1787956846.8318183'
# 2026-08-28 22:40:46,901 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 1d105e5ce3a9a77c7513386ce7204b6a initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 2, 4, 3, 3, 8, 13) executed on worker tcp://127.0.0.1:36099
# 2026-08-28 22:40:46,999 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 269896f5e3b7e6c2c03bd0af545e63b2 initialized by task ('rechunk-merge-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 2, 3, 3, 3, 6, 16) executed on worker tcp://127.0.0.1:40095
# 2026-08-28 22:40:47,026 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 161f79cf220ef793df7f53a906364b40 initialized by task ('rechunk-merge-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 2, 3, 2, 3, 6, 12) executed on worker tcp://127.0.0.1:40095
# 2026-08-28 22:40:47,031 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 5c4d1b42cab3f3556eb233646d774d63 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 4, 2, 2, 6, 5, 9) executed on worker tcp://127.0.0.1:44797
# 2026-08-28 22:40:47,044 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 84eda7debc74332812432e0a83ed1b0b initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 4, 2, 1, 6, 5, 8) executed on worker tcp://127.0.0.1:44797
# 2026-08-28 22:40:47,090 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 7fbe427b6c11536bb54d16390ac27bfe initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 2, 4, 2, 3, 8, 12) executed on worker tcp://127.0.0.1:36099
# 2026-08-28 22:40:47,097 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 9bbd8643419f697b35141b917d26fba0 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 2, 2, 3, 3, 5, 17) executed on worker tcp://127.0.0.1:36099
# 2026-08-28 22:40:47,131 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 31e84317b3fc08d4771f36c1cd090145 deactivated due to stimulus 'task-finished-1787956847.1040883'
# 2026-08-28 22:40:47,181 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle a0943c6ac3d74a016e2730ed1a33535e initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 4, 4, 1, 6, 8, 8) executed on worker tcp://127.0.0.1:39791
# 2026-08-28 22:40:47,187 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle bc0333080fc81c977cfd753321a7871c initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 4, 3, 1, 6, 7, 8) executed on worker tcp://127.0.0.1:39791
# 2026-08-28 22:40:47,236 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 501a1b026f5978faa4584cf770c2d210 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 4, 1, 3, 6, 3, 13) executed on worker tcp://127.0.0.1:44797
# 2026-08-28 22:40:47,238 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 8531544afd5ceca8262b4b23e3d91704 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 4, 1, 2, 6, 3, 12) executed on worker tcp://127.0.0.1:44797
# 2026-08-28 22:40:47,258 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle ea68e3ebbc316e310df841068cb16290 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 2, 2, 2, 3, 5, 12) executed on worker tcp://127.0.0.1:40095
# 2026-08-28 22:40:47,277 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 5ef8ce6fcb446363194ad987863bce41 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 2, 1, 3, 3, 3, 14) executed on worker tcp://127.0.0.1:39791
# 2026-08-28 22:40:47,412 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle dfdc24ff3999cb5ff68d24a137bf269a initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 2, 2, 1, 3, 5, 8) executed on worker tcp://127.0.0.1:42581
# 2026-08-28 22:40:47,413 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 4a8117a794353ed57cad0ad340e05e89 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 4, 1, 1, 6, 3, 8) executed on worker tcp://127.0.0.1:41177
# 2026-08-28 22:40:47,418 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 7242e3fe47db76fb40944f75d0c4e44f initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 2, 1, 2, 3, 3, 12) executed on worker tcp://127.0.0.1:41177
# 2026-08-28 22:40:47,457 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 79f952ec6883e96ac262cb1166ead100 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 2, 4, 1, 3, 8, 8) executed on worker tcp://127.0.0.1:39791
# 2026-08-28 22:40:47,459 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle ee195ed5740ec1bacbf521f5689cdbd8 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 2, 3, 1, 3, 7, 8) executed on worker tcp://127.0.0.1:39791
# 2026-08-28 22:40:47,597 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 1d105e5ce3a9a77c7513386ce7204b6a deactivated due to stimulus 'task-finished-1787956847.5805259'
# 2026-08-28 22:40:47,601 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 80f2408c88623bcb2bfa16d70dfffc38 deactivated due to stimulus 'task-finished-1787956847.5820777'
# 2026-08-28 22:40:47,603 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle a1cc184d13c6f6211e7833ff27ce8923 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 2, 1, 1, 3, 3, 8) executed on worker tcp://127.0.0.1:40095
# 2026-08-28 22:40:47,668 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle c4525f150ed2d73856a7e6e9604839df initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 2, 4, 0, 3, 8, 3) executed on worker tcp://127.0.0.1:39791
# 2026-08-28 22:40:47,669 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle b349a030859bee32bf2e19e25a65deb0 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 2, 3, 0, 3, 7, 3) executed on worker tcp://127.0.0.1:39791
# 2026-08-28 22:40:47,690 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 99efc8a0b119a9e5a92a6adc0b427ab7 deactivated due to stimulus 'task-finished-1787956847.6620114'
# 2026-08-28 22:40:47,748 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 3fb301ecc921894303e4030cfd0cca01 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 2, 2, 0, 3, 5, 3) executed on worker tcp://127.0.0.1:39791
# 2026-08-28 22:40:47,805 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 7adc5c94608a66d34b2262e7fd2b80e4 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 2, 0, 3, 3, 1, 14) executed on worker tcp://127.0.0.1:36099
# 2026-08-28 22:40:47,851 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 90259db2d247c92e82cb7a9358bbf50c initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 2, 1, 0, 3, 3, 1) executed on worker tcp://127.0.0.1:40095
# 2026-08-28 22:40:47,896 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 135ae5f166a7d216ea036f06fb536e3a deactivated due to stimulus 'task-finished-1787956847.8859248'
# 2026-08-28 22:40:48,025 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 7fbe427b6c11536bb54d16390ac27bfe deactivated due to stimulus 'task-finished-1787956848.016024'
# 2026-08-28 22:40:48,051 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 4e5b0bf81bca8261c2b61e4be07b1195 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 2, 0, 2, 3, 1, 11) executed on worker tcp://127.0.0.1:36099
# 2026-08-28 22:40:48,055 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 4628d61fdc5d66035ca1984e693cb1b7 deactivated due to stimulus 'task-finished-1787956848.0336587'
# 2026-08-28 22:40:48,121 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 79f952ec6883e96ac262cb1166ead100 deactivated due to stimulus 'task-finished-1787956848.103043'
# 2026-08-28 22:40:48,240 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 948b5215ebfdf6ada33b329b5c1f7dbf initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 2, 0, 1, 3, 1, 8) executed on worker tcp://127.0.0.1:39791
# 2026-08-28 22:40:48,344 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 269896f5e3b7e6c2c03bd0af545e63b2 deactivated due to stimulus 'task-finished-1787956848.3402572'
# 2026-08-28 22:40:48,411 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle cf032a5b84ae81577525126d7eb451ae initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 4, 4, 0, 6, 8, 3) executed on worker tcp://127.0.0.1:39791
# 2026-08-28 22:40:48,415 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle f4cb6ae0c37bc6349ce7e0114aaaf3b1 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 4, 3, 0, 6, 7, 3) executed on worker tcp://127.0.0.1:39791
# 2026-08-28 22:40:48,460 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 1a27a5ab0bb6565897e3a496a9597b6e initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 4, 2, 0, 6, 5, 3) executed on worker tcp://127.0.0.1:41309
# 2026-08-28 22:40:48,559 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle e1bcec1b9382563e681942571ffb4893 deactivated due to stimulus 'task-finished-1787956848.5501328'
# 2026-08-28 22:40:48,617 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle c4525f150ed2d73856a7e6e9604839df deactivated due to stimulus 'task-finished-1787956848.5891893'
# 2026-08-28 22:40:48,618 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 5c4d1b42cab3f3556eb233646d774d63 deactivated due to stimulus 'task-finished-1787956848.597293'
# 2026-08-28 22:40:48,641 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle ee195ed5740ec1bacbf521f5689cdbd8 deactivated due to stimulus 'task-finished-1787956848.6353958'
# 2026-08-28 22:40:48,642 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle dfdc24ff3999cb5ff68d24a137bf269a deactivated due to stimulus 'task-finished-1787956848.6358516'
# 2026-08-28 22:40:48,658 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 3fb301ecc921894303e4030cfd0cca01 deactivated due to stimulus 'task-finished-1787956848.6560237'
# 2026-08-28 22:40:48,742 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle a0943c6ac3d74a016e2730ed1a33535e deactivated due to stimulus 'task-finished-1787956848.7409084'
# 2026-08-28 22:40:48,777 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 161f79cf220ef793df7f53a906364b40 deactivated due to stimulus 'task-finished-1787956848.7394927'
# 2026-08-28 22:40:48,960 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 7adc5c94608a66d34b2262e7fd2b80e4 deactivated due to stimulus 'task-finished-1787956848.9559948'
# 2026-08-28 22:40:48,981 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 7242e3fe47db76fb40944f75d0c4e44f deactivated due to stimulus 'task-finished-1787956848.9627626'
# 2026-08-28 22:40:48,997 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle b349a030859bee32bf2e19e25a65deb0 deactivated due to stimulus 'task-finished-1787956848.9922888'
# 2026-08-28 22:40:49,020 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle da5439303d3ba82af396d1f3d84c269b initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 4, 1, 0, 6, 3, 3) executed on worker tcp://127.0.0.1:44797
# 2026-08-28 22:40:49,155 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 4e5b0bf81bca8261c2b61e4be07b1195 deactivated due to stimulus 'task-finished-1787956849.1536622'
# 2026-08-28 22:40:49,196 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 9bbd8643419f697b35141b917d26fba0 deactivated due to stimulus 'task-finished-1787956849.1908932'
# 2026-08-28 22:40:49,267 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 5ef8ce6fcb446363194ad987863bce41 deactivated due to stimulus 'task-finished-1787956849.2636113'
# 2026-08-28 22:40:49,327 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle ea68e3ebbc316e310df841068cb16290 deactivated due to stimulus 'task-finished-1787956849.325377'
# 2026-08-28 22:40:49,385 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle cf032a5b84ae81577525126d7eb451ae deactivated due to stimulus 'task-finished-1787956849.3772316'
# 2026-08-28 22:40:49,411 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle f4cb6ae0c37bc6349ce7e0114aaaf3b1 deactivated due to stimulus 'task-finished-1787956849.3995924'
# 2026-08-28 22:40:49,420 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle bc0333080fc81c977cfd753321a7871c deactivated due to stimulus 'task-finished-1787956849.4125721'
# 2026-08-28 22:40:49,443 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 84eda7debc74332812432e0a83ed1b0b deactivated due to stimulus 'task-finished-1787956849.436341'
# 2026-08-28 22:40:49,598 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 5ea3774e9e521d62f22bee9b1b78b6d7 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 4, 0, 1, 6, 1, 4) executed on worker tcp://127.0.0.1:40095
# 2026-08-28 22:40:49,619 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 0a87df0d098240c5701bd05741382091 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 4, 0, 0, 6, 1, 2) executed on worker tcp://127.0.0.1:41177
# 2026-08-28 22:40:49,700 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle e86f8d997bfa7cf1407b63502837031b initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 2, 0, 0, 3, 1, 3) executed on worker tcp://127.0.0.1:40095
# 2026-08-28 22:40:49,713 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 15c78a15ea2fa87b278bff68af0992bf initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 4, 0, 2, 6, 1, 9) executed on worker tcp://127.0.0.1:39791
# 2026-08-28 22:40:49,876 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle d8c8f5cb61dacf7e7797dd8f478cb6d1 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 4, 0, 3, 6, 1, 17) executed on worker tcp://127.0.0.1:39791
# 2026-08-28 22:40:49,985 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 2384e21528ed26ae7e724814f1c6861e initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 0, 2, 3, 0, 5, 17) executed on worker tcp://127.0.0.1:42581
# 2026-08-28 22:40:49,992 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 10a1cc2d4e44f4973ffc31a79fe6d632 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 0, 3, 3, 0, 7, 14) executed on worker tcp://127.0.0.1:41177
# 2026-08-28 22:40:50,017 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 80c46ac67b7d4065fcd52ae95fb8a488 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 0, 4, 3, 0, 8, 14) executed on worker tcp://127.0.0.1:41177
# 2026-08-28 22:40:50,073 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 06720f98cad1b1d31f7fc339f37f87d4 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 0, 3, 2, 0, 7, 12) executed on worker tcp://127.0.0.1:42581
# 2026-08-28 22:40:50,077 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 1bc8e3f8e6ae07df508e3e7baff56735 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 0, 4, 2, 0, 8, 12) executed on worker tcp://127.0.0.1:42581
# 2026-08-28 22:40:50,114 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 7ff9ba251e78df99f3e472835ab554b3 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 0, 1, 3, 0, 3, 17) executed on worker tcp://127.0.0.1:41177
# 2026-08-28 22:40:50,240 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle e6e2469b4817b1d7c299ad97e43a608e initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 0, 2, 2, 0, 5, 12) executed on worker tcp://127.0.0.1:40095
# 2026-08-28 22:40:50,276 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 1a27a5ab0bb6565897e3a496a9597b6e deactivated due to stimulus 'task-finished-1787956850.2495406'
# 2026-08-28 22:40:50,292 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 53804900bce888b79d6c8b20097bd67f initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 0, 2, 1, 0, 5, 7) executed on worker tcp://127.0.0.1:42581
# 2026-08-28 22:40:50,368 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 22ea982b5d3fd01fb58152298f883ef1 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 0, 4, 1, 0, 8, 8) executed on worker tcp://127.0.0.1:41177
# 2026-08-28 22:40:50,370 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle fb29cca40a6f459d2f4ac54dc6aa81b9 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 0, 3, 1, 0, 7, 8) executed on worker tcp://127.0.0.1:41177
# 2026-08-28 22:40:50,379 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 4673191237a8e00228e28d7645fa60db initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 0, 3, 0, 0, 7, 3) executed on worker tcp://127.0.0.1:41309
# 2026-08-28 22:40:50,384 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 07ab95fc8f845f65d50a990726a5a677 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 0, 4, 0, 0, 8, 3) executed on worker tcp://127.0.0.1:41309
# 2026-08-28 22:40:51,341 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 9f4ff356ca6a7964201e8888ec376287 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 0, 1, 2, 0, 3, 11) executed on worker tcp://127.0.0.1:42581
# 2026-08-28 22:40:51,342 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 3fa629bd9ed8586bee038014ca54d5ce initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-64ebe0206ecb627ec6f8c036a9e140b9', 0, 1, 1, 0, 3, 8) executed on worker tcp://127.0.0.1:42581
# 2026-08-28 22:40:51,353 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle da5439303d3ba82af396d1f3d84c269b deactivated due to stimulus 'task-finished-1787956850.4189796'
# 2026-08-28 22:40:51,368 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 4a8117a794353ed57cad0ad340e05e89 deactivated due to stimulus 'task-finished-1787956850.43564'
# ...
# 2026-08-28 23:09:32,792 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 426500879cefa0bb337e5449907ec1be initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 0, 2, 3, 0, 5, 17) executed on worker tcp://127.0.0.1:36099
# 2026-08-28 23:09:32,793 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 9f34b4d88cd730466f3509b44aa15a27 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 2, 2, 2, 3, 5, 11) executed on worker tcp://127.0.0.1:40095
# 2026-08-28 23:09:32,797 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 5ad758d2b55768af8faf02c84021bf73 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 0, 1, 2, 0, 3, 10) executed on worker tcp://127.0.0.1:36099
# 2026-08-28 23:09:32,798 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 8751d8de82835d21aa2a0b0ccf784cb2 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 0, 4, 2, 0, 8, 12) executed on worker tcp://127.0.0.1:40095
# 2026-08-28 23:09:32,799 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 19c92ae538a3a37075659a5f8750dae4 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 0, 1, 1, 0, 3, 8) executed on worker tcp://127.0.0.1:41309
# 2026-08-28 23:09:32,799 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 40a1aed5254cbf6d24e78ed2d001e312 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 2, 1, 3, 3, 3, 16) executed on worker tcp://127.0.0.1:41309
# 2026-08-28 23:09:32,804 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 292465136af93dba4622012166ccbf9e initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 2, 3, 2, 3, 7, 12) executed on worker tcp://127.0.0.1:42581
# 2026-08-28 23:09:32,828 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle ebecde3d5e020be651e19e5acf9b7ec3 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 0, 2, 2, 0, 5, 11) executed on worker tcp://127.0.0.1:39791
# 2026-08-28 23:09:32,980 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 97a23fe352476762a32341ab79626d5b initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 2, 1, 1, 3, 3, 8) executed on worker tcp://127.0.0.1:42581
# 2026-08-28 23:09:33,012 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 23c35d227e2f659a7413b942e534a436 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 2, 0, 3, 3, 1, 16) executed on worker tcp://127.0.0.1:41177
# 2026-08-28 23:09:33,013 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 28e9b652dd59be951233ef0c768a2ae5 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 0, 2, 1, 0, 5, 8) executed on worker tcp://127.0.0.1:39791
# 2026-08-28 23:09:33,018 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle b95a44142bd271a0ccf1a0c5935c39dc initialized by task ('rechunk-merge-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 2, 2, 1, 3, 4, 8) executed on worker tcp://127.0.0.1:42581
# 2026-08-28 23:09:33,069 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 70d8cb9ae4441ce65726a7765d3578f1 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 2, 4, 1, 3, 8, 8) executed on worker tcp://127.0.0.1:44797
# 2026-08-28 23:09:33,075 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle e11ce55330b42f44f4bb30255f905973 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 0, 4, 1, 0, 8, 8) executed on worker tcp://127.0.0.1:44797
# 2026-08-28 23:09:33,076 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 3b4c9f0dd15921d034fb93c5b627462e initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 2, 3, 1, 3, 7, 8) executed on worker tcp://127.0.0.1:44797
# 2026-08-28 23:09:33,083 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 4d683a858e5936a4d8c96642785f5083 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 0, 3, 1, 0, 7, 8) executed on worker tcp://127.0.0.1:44797
# 2026-08-28 23:09:33,136 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle e69c2b1a9ce3d69db83631831b7f7e8c initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 0, 0, 2, 0, 1, 12) executed on worker tcp://127.0.0.1:41177
# 2026-08-28 23:09:33,139 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle d73a767efc298a7c32362631397cd488 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 0, 0, 3, 0, 1, 13) executed on worker tcp://127.0.0.1:41177
# 2026-08-28 23:09:33,235 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 2cb9c1a32bbefe61dc914cb15eb954ad initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 2, 0, 2, 3, 1, 12) executed on worker tcp://127.0.0.1:36099
# 2026-08-28 23:09:33,245 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle a87b93a027f6f2cb628e4653f525007f initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 0, 0, 1, 0, 1, 8) executed on worker tcp://127.0.0.1:41177
# 2026-08-28 23:09:33,281 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 77729dc82693479a6fd34801aad6fa18 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 2, 0, 1, 3, 1, 8) executed on worker tcp://127.0.0.1:44797
# 2026-08-28 23:09:33,701 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 178769dc43dab819ba4adca1ae6ec19e initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 0, 0, 0, 0, 1, 3) executed on worker tcp://127.0.0.1:39791
# 2026-08-28 23:09:33,707 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 6f2c13d14075cec7c9649386577504e8 deactivated due to stimulus 'task-finished-1787958573.7001035'
# 2026-08-28 23:09:33,724 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 10d19fab0d712b765fe89aa74ee3eac2 deactivated due to stimulus 'task-finished-1787958573.6688652'
# 2026-08-28 23:09:33,733 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 8751d8de82835d21aa2a0b0ccf784cb2 deactivated due to stimulus 'task-finished-1787958573.711171'
# 2026-08-28 23:09:33,808 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle b80d89d7ebeff613230b2113e3d78848 deactivated due to stimulus 'task-finished-1787958573.7700877'
# 2026-08-28 23:09:33,835 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle eaac482bee1d556d48e1ca0c9a43bb34 initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 2, 0, 0, 3, 1, 3) executed on worker tcp://127.0.0.1:41177
# 2026-08-28 23:09:33,839 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle ba95e324935c7dad323987d480b915ef initialized by task ('rechunk-merge-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 2, 1, 0, 3, 2, 3) executed on worker tcp://127.0.0.1:41177
# 2026-08-28 23:09:33,883 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle fdc68ac5293ff39424f851b425ebe5ba initialized by task ('rechunk-merge-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 0, 1, 0, 0, 2, 3) executed on worker tcp://127.0.0.1:36099
# 2026-08-28 23:09:34,041 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 23c35d227e2f659a7413b942e534a436 deactivated due to stimulus 'task-finished-1787958574.033182'
# 2026-08-28 23:09:34,097 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 3e79333fbcc79c602df1e06965b64a1f deactivated due to stimulus 'task-finished-1787958574.0853562'
# 2026-08-28 23:09:34,135 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 3bf4d55c5f83c6171a807d32aef01267 deactivated due to stimulus 'task-finished-1787958574.1111221'
# 2026-08-28 23:09:34,176 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 9f34b4d88cd730466f3509b44aa15a27 deactivated due to stimulus 'task-finished-1787958574.1746051'
# 2026-08-28 23:09:34,183 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle d5e0077aca6309ffb8df1dc4108d3fba deactivated due to stimulus 'task-finished-1787958574.170126'
# 2026-08-28 23:09:34,197 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 40a1aed5254cbf6d24e78ed2d001e312 deactivated due to stimulus 'task-finished-1787958574.1945317'
# 2026-08-28 23:09:34,218 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 292465136af93dba4622012166ccbf9e deactivated due to stimulus 'task-finished-1787958574.215602'
# 2026-08-28 23:09:34,338 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle dd36d51cb676fbd22b37c944030b65df deactivated due to stimulus 'task-finished-1787958574.3300452'
# 2026-08-28 23:09:34,482 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 426500879cefa0bb337e5449907ec1be deactivated due to stimulus 'task-finished-1787958574.4639041'
# 2026-08-28 23:09:34,497 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 9267de6fda525adafd39598d5da68bbc deactivated due to stimulus 'task-finished-1787958574.4876993'
# 2026-08-28 23:09:34,688 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle ebecde3d5e020be651e19e5acf9b7ec3 deactivated due to stimulus 'task-finished-1787958574.6769178'
# 2026-08-28 23:09:35,107 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 5ad758d2b55768af8faf02c84021bf73 deactivated due to stimulus 'task-finished-1787958575.106168'
# 2026-08-28 23:09:35,127 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle d73a767efc298a7c32362631397cd488 deactivated due to stimulus 'task-finished-1787958575.1121602'
# 2026-08-28 23:09:35,158 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 7f979524cc91947a0076d91c0f0fdc2f deactivated due to stimulus 'task-finished-1787958575.157003'
# 2026-08-28 23:09:35,160 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle e69c2b1a9ce3d69db83631831b7f7e8c deactivated due to stimulus 'task-finished-1787958575.1495106'
# 2026-08-28 23:09:35,283 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 2cb9c1a32bbefe61dc914cb15eb954ad deactivated due to stimulus 'task-finished-1787958575.2782276'
# 2026-08-28 23:09:35,591 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 97a23fe352476762a32341ab79626d5b deactivated due to stimulus 'task-finished-1787958575.5460958'
# 2026-08-28 23:09:35,910 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 56e54f97f39b25588be01c2bc57a53ad initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 2, 4, 0, 3, 8, 3) executed on worker tcp://127.0.0.1:44797
# 2026-08-28 23:09:35,911 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 2b2cec05b2e4369442e4e14f625238be initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 2, 3, 0, 3, 7, 3) executed on worker tcp://127.0.0.1:44797
# 2026-08-28 23:09:35,920 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 951b500a711257e8ef3799209f2e9c1a initialized by task ('rechunk-merge-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 0, 3, 0, 0, 6, 3) executed on worker tcp://127.0.0.1:41309
# 2026-08-28 23:09:35,925 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle b76edb447e57448677e2da1cf309799c initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 0, 4, 0, 0, 8, 3) executed on worker tcp://127.0.0.1:39479
# 2026-08-28 23:09:35,933 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 145c967360ebd400015eea0d960effdf initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 2, 2, 0, 3, 5, 1) executed on worker tcp://127.0.0.1:40095
# 2026-08-28 23:09:35,944 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 19c92ae538a3a37075659a5f8750dae4 deactivated due to stimulus 'task-finished-1787958575.9057577'
# 2026-08-28 23:09:36,002 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle d5b511a3eba206ada8b5fcd2bad8f5bd initialized by task ('rechunk-merge-rechunk-split-rechunk-transfer-e08d0a956c6f2e5c86d21840730c7418', 0, 2, 0, 0, 5, 3) executed on worker tcp://127.0.0.1:41309
# 2026-08-28 23:09:36,465 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle e11ce55330b42f44f4bb30255f905973 deactivated due to stimulus 'task-finished-1787958576.4585204'
# 2026-08-28 23:09:36,505 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle ba95e324935c7dad323987d480b915ef deactivated due to stimulus 'task-finished-1787958576.4964483'
# 2026-08-28 23:09:36,515 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle eaac482bee1d556d48e1ca0c9a43bb34 deactivated due to stimulus 'task-finished-1787958576.4878492'
# 2026-08-28 23:09:36,535 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle fdc68ac5293ff39424f851b425ebe5ba deactivated due to stimulus 'task-finished-1787958576.5126202'
# 2026-08-28 23:09:36,547 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 178769dc43dab819ba4adca1ae6ec19e deactivated due to stimulus 'task-finished-1787958576.5169482'
# 2026-08-28 23:09:36,551 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 70d8cb9ae4441ce65726a7765d3578f1 deactivated due to stimulus 'task-finished-1787958576.5193214'
# 2026-08-28 23:09:36,556 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle a87b93a027f6f2cb628e4653f525007f deactivated due to stimulus 'task-finished-1787958576.5415378'
# 2026-08-28 23:09:36,557 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 77729dc82693479a6fd34801aad6fa18 deactivated due to stimulus 'task-finished-1787958576.5416121'
# 2026-08-28 23:09:36,932 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 3b4c9f0dd15921d034fb93c5b627462e deactivated due to stimulus 'task-finished-1787958576.923937'
# 2026-08-28 23:09:36,995 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 56e54f97f39b25588be01c2bc57a53ad deactivated due to stimulus 'task-finished-1787958576.9905794'
# 2026-08-28 23:09:37,028 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 4d683a858e5936a4d8c96642785f5083 deactivated due to stimulus 'task-finished-1787958577.0226798'
# 2026-08-28 23:09:37,029 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle b95a44142bd271a0ccf1a0c5935c39dc deactivated due to stimulus 'task-finished-1787958577.0230505'
# 2026-08-28 23:09:37,409 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle b76edb447e57448677e2da1cf309799c deactivated due to stimulus 'task-finished-1787958577.4037635'
# 2026-08-28 23:09:37,423 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 2b2cec05b2e4369442e4e14f625238be deactivated due to stimulus 'task-finished-1787958577.4201736'
# 2026-08-28 23:09:37,444 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle d5b511a3eba206ada8b5fcd2bad8f5bd deactivated due to stimulus 'task-finished-1787958577.4323416'
# 2026-08-28 23:09:37,454 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 145c967360ebd400015eea0d960effdf deactivated due to stimulus 'task-finished-1787958577.4441712'
# 2026-08-28 23:09:37,503 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 951b500a711257e8ef3799209f2e9c1a deactivated due to stimulus 'task-finished-1787958577.4810297'
# 2026-08-28 23:09:37,615 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 28e9b652dd59be951233ef0c768a2ae5 deactivated due to stimulus 'task-finished-1787958577.607021'

# %%
# CACHE_DIR is an s3:// prefix -- this notebook runs on a temporary remote machine with no
# room for ~10GB of local pkl cache. url_to_fs resolves the filesystem once (credentials,
# protocol) instead of on every one of the ~100 compute_or_load calls below.
_cache_fs, _cache_root = fsspec.core.url_to_fs(CACHE_DIR)


def _cache_path(key: str) -> str:
    return f"{_cache_root}/{key.replace('/', '__')}.pkl"


def compute_or_load(key: str, compute_fn):
    """Compute once, cache to CACHE_DIR, and reuse on every later run (incl. after a kernel restart).

    Safe to call repeatedly: a cache hit is just a pickle load from S3, no dask/icechunk touched.
    """
    path = _cache_path(key)
    if _cache_fs.exists(path):
        with _cache_fs.open(path, "rb") as f:
            return pickle.load(f)
    result = compute_fn()
    with _cache_fs.open(path, "wb") as f:
        pickle.dump(result, f)
    return result

# %% [markdown]
# ## Discover tags and open every intermediate flag store
#
# `discover_leaves` enumerates every `(gcm, scenario, variable, ensemble, method)` leaf by
# opening the raw/debiased data trees -- this is metadata-only (no data is loaded), it just
# tells us which tags exist. We then open each tag's intermediate flag store in parallel
# threads (also metadata-only: it just registers the zarr group's variables, lazily).

# %%
[trees, tags, gcms_np, scenarios_np, variables_np, tags_np, methods_np, debiased_coarse_flags_np] = (
    discover_leaves(gcms=GCMS, branch=BRANCH, root_dir=ROOT_DIR, store_subset_id=STORE_SUBSET_ID)
)

tag_meta = pd.DataFrame(
    {
        "tag": tags,
        "gcm": gcms_np,
        "variable": variables_np,
        "scenario": scenarios_np,
        "method": methods_np,
        "ensemble_member": [parse_tag(t)[3] for t in tags],
    }
)
tag_meta = tag_meta[tag_meta["variable"].isin(VARIABLES)].reset_index(drop=True)
print(f"{len(tag_meta)} tags to open")
tag_meta.head()
# Out:
# opened 1/1 stores on branch 'pr-638-global': CESM2-WACCM
# 196 leaves across 1 GCMs
# 71 tags to open
# /scratch/synced/src/srm/qa_flags.py:636: UserWarning: The specified chunks separate the stored chunks along dimension "lat" starting at index 180. This could degrade performance. Instead, consider rechunking after loading.
#   trees[gcm] = xr.open_datatree(session.store, engine="zarr", chunks=INPUT_CHUNKS)
# /scratch/synced/src/srm/qa_flags.py:636: UserWarning: The specified chunks separate the stored chunks along dimension "lon" starting at index 360. This could degrade performance. Instead, consider rechunking after loading.
#   trees[gcm] = xr.open_datatree(session.store, engine="zarr", chunks=INPUT_CHUNKS)
#                                   tag          gcm variable scenario method  \
# 0    CESM2-WACCM_pr_g6_1p5k_001_qdmsd  CESM2-WACCM       pr  g6_1p5k  qdmsd
# 1    CESM2-WACCM_pr_g6_1p5k_002_qdmsd  CESM2-WACCM       pr  g6_1p5k  qdmsd
# 2    CESM2-WACCM_pr_g6_1p5k_003_qdmsd  CESM2-WACCM       pr  g6_1p5k  qdmsd
# 3  CESM2-WACCM_rsds_g6_1p5k_002_qdmsd  CESM2-WACCM     rsds  g6_1p5k  qdmsd
# 4  CESM2-WACCM_rsds_g6_1p5k_001_qdmsd  CESM2-WACCM     rsds  g6_1p5k  qdmsd
#
#   ensemble_member
# 0             001
# 1             002
# 2             003
# 3             002
# 4             001

# %%
def _open_flags(tag):
    ds = get_intermediate_flags(tag=tag, bucket=FLAG_BUCKET, prefix=FLAG_PREFIX)
    # Rechunk to the same shard-aligned layout discover_leaves uses for the raw data trees,
    # instead of trusting xr.open_zarr's default chunk selection -- see the "Dask cluster"
    # note above for why an unbounded/misaligned chunking is the likely OOM culprit.
    rechunk = {dim: size for dim, size in INPUT_CHUNKS.items() if dim in ds.sizes}
    return tag, ds.chunk(rechunk)


flag_datasets = {}
open_errors = {}
with ThreadPoolExecutor(max_workers=N_IO_THREADS) as pool:
    futures = {pool.submit(_open_flags, tag): tag for tag in tag_meta["tag"]}
    for future in as_completed(futures):
        tag = futures[future]
        try:
            _, ds = future.result()
            flag_datasets[tag] = ds
        except Exception as exc:  # noqa: BLE001 -- report every failure, don't stop at the first
            open_errors[tag] = f"{type(exc).__name__}: {exc}"

for tag, err in open_errors.items():
    print(f"FAILED to open intermediate flags for {tag}: {err}")

print(f"opened {len(flag_datasets)}/{len(tag_meta)} intermediate flag stores")
# Out:
# opened 71/71 intermediate flag stores

# %% [markdown]
# ## Land mask and area weights
#
# Same coastline-rasterization approach as `flag_step4_evaluate_flag_prevalence.ipynb`
# (including its `rusterize` patch), computed once and reused everywhere below -- both for
# land-only scalar stats in the summary table, and as `cos(lat)` area weights when
# collapsing a Hovmoller array down to a single global time series.
#
# The `rusterize` patch only takes effect in *this* process: it mutates the `rusterize`
# module object in memory here, but the notebook now runs its dask work on a distributed
# `LocalCluster` (see the "Dask cluster" section above), whose workers are separate
# processes that import their own unpatched copy of `rusterize`. `geometry_mask` picks
# between an eager, in-process path and a lazy, dask-`map_blocks` path based on whether its
# template array is already in memory (`rasterix.rasterize.utils.is_in_memory`, literally
# `not obj.chunks`) -- and our template is a rechunked, still-lazy flag array, so it would
# take the lazy path and get rasterized on an unpatched worker, raising exactly the "`res`
# and `out_shape` are mutually exclusive" error the patch exists to prevent. Loading the
# tiny (720x1440x1 byte) template into memory *before* building it forces the eager,
# in-process path instead, where the patch applies.

# %%
_original_rusterize = _rusterize_pkg.rusterize


def _rusterize_patched(*args, **kwargs):
    if kwargs.get("res") is not None and kwargs.get("out_shape") is not None:
        kwargs = dict(kwargs)
        kwargs.pop("res")
    return _original_rusterize(*args, **kwargs)


_rusterize_pkg.rusterize = _rusterize_patched

ocean_mask_geoparquet = catalog.get("ocean-mask")

_template_tag = tag_meta["tag"].iloc[0]
target_grid_da = flag_datasets[_template_tag][FLAG_LIST_TIME_VARYING[0]]
if "time" in target_grid_da.dims:
    target_grid_da = target_grid_da.isel(time=0, drop=True)
target_grid_da = target_grid_da.compute()  # force in-memory so geometry_mask runs eagerly, in-process

# rusterize requires lat sorted descending
template = target_grid_da.sortby("lat", ascending=False).proj.assign_crs(spatial_ref="epsg:4326")
land_mask = ~geometry_mask(
    template,
    ocean_mask_geoparquet.to_geodataframe()[["geom"]],
    all_touched=True,
    engine="rusterize",
    xdim="lon",
    ydim="lat",
).drop_vars("spatial_ref", errors="ignore")
land_mask = land_mask.load().astype(np.uint8)

# cos(lat) area weights, normalized to mean 1 so a weighted mean is just (x * w).sum() / w.sum()
lat_weights = np.cos(np.deg2rad(land_mask["lat"]))
lat_weights = lat_weights / lat_weights.mean()

# %% [markdown]
# ## Build the flag x variable x scenario catalog
#
# Two catalogs, one per flag structure:
#
# - **Time-varying** flags (`FLAG_LIST_TIME_VARYING`, dims `time, lat, lon`): one combo per
#   `(flag_name, gcm, variable, scenario)`, with every ensemble member's tag attached.
# - **Time-invariant** flags (`FLAG_LIST_TIME_INVARIANT`, dims `lat, lon`): these come from
#   an ensemble-mean scenario-pair comparison, and `flag_step2` writes the *identical* map
#   redundantly into every ensemble member of **both** scenarios in the comparison (see its
#   "Write out flags" cell). So one combo per `(flag_name, gcm, variable)`, pointing at a
#   single representative tag -- reading every duplicate copy would just rescan identical
#   data for no benefit.
#
# This is all cheap bookkeeping (pandas groupby over already-opened, still-lazy datasets) --
# none of it touches dask.compute() -- so it runs in full here rather than being restricted
# to the quick-preview subset below.

# %%
time_varying_combos = []
for flag_name in FLAG_LIST_TIME_VARYING:
    for (gcm, var, scenario), group in tag_meta.groupby(["gcm", "variable", "scenario"]):
        member_tags = [
            t for t in group["tag"] if t in flag_datasets and flag_name in flag_datasets[t].data_vars
        ]
        if member_tags:
            time_varying_combos.append(
                {
                    "flag_name": flag_name,
                    "gcm": gcm,
                    "variable": var,
                    "scenario": scenario,
                    "member_tags": member_tags,
                }
            )

print(f"{len(time_varying_combos)} (flag x gcm x variable x scenario) time-varying combos")
# Out:
# 47 (flag x gcm x variable x scenario) time-varying combos

# %%
time_invariant_combos = []
seen = set()
for flag_name in FLAG_LIST_TIME_INVARIANT:
    for (gcm, var), group in tag_meta.groupby(["gcm", "variable"]):
        key = (flag_name, gcm, var)
        if key in seen:
            continue
        rep_tag = next(
            (
                t
                for t in group["tag"]
                if t in flag_datasets and flag_name in flag_datasets[t].data_vars
            ),
            None,
        )
        if rep_tag is not None:
            time_invariant_combos.append(
                {"flag_name": flag_name, "gcm": gcm, "variable": var, "representative_tag": rep_tag}
            )
            seen.add(key)

print(f"{len(time_invariant_combos)} (flag x gcm x variable) time-invariant combos")
# Out:
# 24 (flag x gcm x variable) time-invariant combos

# %% [markdown]
# ## Helper functions (compute + plot)
#
# Everything in this section only *defines* functions -- nothing here calls
# `dask.compute()` or touches the flag stores by itself. They're defined once, up front, and
# used by both the Quick preview right after and the Full run further down, so the two
# sections can't drift out of sync with each other.

# %% [markdown]
# ### Time-varying combo compute
#
# For each combo, every member's **time-mean map** (frac of days flagged per pixel),
# **lon-mean Hovmoller** (time x lat), and land/global **scalar rates** are built as lazy
# dask expressions from the *same* underlying `xr.DataArray` and handed to a single
# `dask.compute()` call together. Dask dedupes shared graph nodes automatically, so each
# chunk is only read and decompressed once per combo no matter how many of these outputs
# depend on it -- that's what avoids duplicating the expensive part of the analysis across
# the map / agreement-map / time-series / Hovmoller / table figures that all ultimately
# come from this one pass.
#
# Ensemble members are concatenated and reduced (mean, and fraction-of-members-flagged for
# agreement) *after* this compute call, so only the small ensemble-mean/agreement arrays --
# not every member's individual map/Hovmoller -- end up in the cache.

# %%
def _combo_key(c):
    return f"tv__{c['flag_name']}__{c['gcm']}__{c['variable']}__{c['scenario']}"


def _compute_time_varying_combo(combo):
    member_arrays = {parse_tag(t)[3]: flag_datasets[t][combo["flag_name"]] for t in combo["member_tags"]}

    lazy = {}
    for ens, da in member_arrays.items():
        lazy[("map", ens)] = da.mean(dim="time")  # frac of days flagged, per pixel
        lazy[("hovmoller", ens)] = da.mean(dim="lon")  # (time, lat), lon-averaged
        lazy[("scalar_total", ens)] = da.mean()  # frac of all pixel-days flagged
        lazy[("scalar_any", ens)] = (da.sum(dim="time") > 0).mean()  # frac of pixels ever flagged
        land_da = da.where(land_mask > 0)
        lazy[("scalar_total_land", ens)] = land_da.mean()
        lazy[("scalar_any_land", ens)] = (land_da.sum(dim="time") > 0).mean()

    keys = list(lazy.keys())
    values = dask.compute(*[lazy[k] for k in keys])
    computed = dict(zip(keys, values, strict=True))

    ens_list = list(member_arrays)
    ens_index = pd.Index(ens_list, name="ensemble_member")
    maps = xr.concat([computed[("map", e)] for e in ens_list], dim=ens_index)
    hovmollers = xr.concat([computed[("hovmoller", e)] for e in ens_list], dim=ens_index)

    per_member_table = pd.DataFrame(
        {
            "ensemble_member": ens_list,
            "frac_flagged": [float(computed[("scalar_total", e)]) for e in ens_list],
            "frac_space_ever_flagged": [float(computed[("scalar_any", e)]) for e in ens_list],
            "frac_flagged_land": [float(computed[("scalar_total_land", e)]) for e in ens_list],
            "frac_space_ever_flagged_land": [float(computed[("scalar_any_land", e)]) for e in ens_list],
        }
    )

    return {
        "ensemble_mean_map": maps.mean(dim="ensemble_member"),
        "agreement_map": (maps > 0).mean(dim="ensemble_member"),
        "ensemble_mean_hovmoller": hovmollers.mean(dim="ensemble_member"),
        "per_member_table": per_member_table,
    }

# %% [markdown]
# ### Time-invariant combo compute
#
# Each of these is already a single `(lat, lon)` map (no time dimension, no ensemble
# dimension -- see the catalog note above), so there's nothing to batch across members;
# this is just a direct load plus two scalar rates per combo.

# %%
def _ti_combo_key(c):
    return f"ti__{c['flag_name']}__{c['gcm']}__{c['variable']}"


def _compute_time_invariant_combo(combo):
    da = flag_datasets[combo["representative_tag"]][combo["flag_name"]]
    (arr,) = dask.compute(da)
    return {
        "map": arr,
        "frac_flagged": float(arr.mean()),
        "frac_flagged_land": float(arr.where(land_mask > 0).mean()),
    }

# %% [markdown]
# ### Derived helpers (cheap -- operate on already-cached, already-reduced arrays)
#
# `hovmoller_to_timeseries` collapses a cached `(time, lat)` Hovmoller array down to a
# single area-weighted global time series. It's deliberately *not* land-masked: the
# Hovmoller pass above already averaged over all of `lon` (land + ocean mixed), so a
# land-only time series would need its own separate masked lon-reduction pass -- not worth
# doubling pass-2's cost for what the land-only *scalar* rates in the table already cover.
# The scenario-boundary zoom just slices this same time series around the g6_1p5k ->
# g6_1p5k_end splice, no extra computation needed.

# %%
def hovmoller_to_timeseries(hovmoller):
    """Area-weighted (cos-lat) collapse of a (time, lat) Hovmoller array to a time series."""
    return (hovmoller * lat_weights).sum(dim="lat") / lat_weights.sum(dim="lat")


def top_n_pixels(map_da, n=15):
    flat = map_da.stack(pixel=("lat", "lon"))
    top = flat.sortby(flat, ascending=False).isel(pixel=slice(0, n))
    return pd.DataFrame(
        {
            "lat": top["lat"].values,
            "lon": top["lon"].values,
            "value": top.values,
        }
    )

# %% [markdown]
# ### Plot style and helpers
#
# `PLOT_STYLE` centralizes labels/colormaps/sizing so restyling a figure later means
# editing one dict plus the relevant `plot_*` function, not hunting through every
# figure-generating loop. `plot_summary_heatmap` reads the `summary_df` table built in the
# Full run section below, so it's defined here but only usable once that section has run.

# %%
PLOT_STYLE = {
    "cmap_map": "Reds",
    "cmap_agreement": "Purples",
    "cmap_hovmoller": "Reds",
    "cmap_invariant": "Oranges",
    "zero_color": "0.85",  # flat gray for confirmed-zero pixels, distinct from any cmap's range
    "figsize_map": (7, 4.5),
    "figsize_grid_cell": (3.2, 2.5),  # taller than the map itself to leave room for each panel's colorbar
    "coastline_linewidth": 0.4,
    "coastline_edgecolor": "0.3",
    "title_fontsize": 10,
    "suptitle_fontsize": 12,
}

# %%
_FIELD_CBAR_LABELS = {
    "ensemble_mean_map": "ensemble-mean fraction of days flagged",
    "agreement_map": "fraction of ensemble members flagged",
}


def plot_map(map_da, title, ax=None, cmap=None, vmin=0, vmax=None, cbar_label="fraction flagged"):
    own_fig = ax is None
    if own_fig:
        plt.figure(figsize=PLOT_STYLE["figsize_map"])
        ax = plt.subplot(1, 1, 1, projection=ccrs.PlateCarree())

    # Flat "zero" color for real (non-NaN) pixels that are exactly 0, plotted *underneath* the
    # colormap layer below -- without this, a confirmed-zero pixel and a genuinely missing/NaN
    # one both render as blank background and are impossible to tell apart.
    zero_mask = map_da.notnull() & (map_da == 0)
    xr.where(zero_mask, 1, np.nan).plot(
        ax=ax,
        transform=ccrs.PlateCarree(),
        cmap=ListedColormap([PLOT_STYLE["zero_color"]]),
        vmin=0,
        vmax=1,
        add_colorbar=False,
    )

    plot_da = map_da.where(map_da > 0)
    im = plot_da.plot(
        ax=ax,
        transform=ccrs.PlateCarree(),
        cmap=cmap or PLOT_STYLE["cmap_map"],
        vmin=vmin,
        vmax=vmax,
        add_colorbar=False,
    )
    ax.add_feature(
        cfeature.COASTLINE,
        linewidth=PLOT_STYLE["coastline_linewidth"],
        edgecolor=PLOT_STYLE["coastline_edgecolor"],
    )
    ax.set_title(title, fontsize=PLOT_STYLE["title_fontsize"])
    plt.colorbar(im, ax=ax, orientation="horizontal", pad=0.05, label=cbar_label, shrink=0.85)
    if own_fig:
        plt.tight_layout()
    return im


def plot_flag_grid(flag_name, gcm, field="ensemble_mean_map", variables=None, scenarios=None, cmap=None):
    variables = variables or VARIABLES
    scenarios = scenarios or SCENARIO_ORDER
    combos = [c for c in time_varying_combos if c["flag_name"] == flag_name and c["gcm"] == gcm]
    present_vars = [v for v in variables if any(c["variable"] == v for c in combos)]
    present_scn = [s for s in scenarios if any(c["scenario"] == s for c in combos)]
    cbar_label = _FIELD_CBAR_LABELS.get(field, "fraction flagged")

    fig, axes = plt.subplots(
        nrows=len(present_vars),
        ncols=len(present_scn),
        figsize=(
            PLOT_STYLE["figsize_grid_cell"][0] * len(present_scn),
            PLOT_STYLE["figsize_grid_cell"][1] * len(present_vars),
        ),
        subplot_kw={"projection": ccrs.PlateCarree()},
        squeeze=False,
    )
    for i, var in enumerate(present_vars):
        for j, scn in enumerate(present_scn):
            ax = axes[i, j]
            combo = next(
                (c for c in combos if c["variable"] == var and c["scenario"] == scn), None
            )
            if combo is None:
                ax.axis("off")
                continue
            res = time_varying_results[_combo_key(combo)]
            plot_map(res[field], title=f"{var} / {scn}", ax=ax, cmap=cmap, cbar_label=cbar_label)
    fig.suptitle(f"{flag_name} -- {field.replace('_', ' ')} ({gcm})", fontsize=PLOT_STYLE["suptitle_fontsize"])
    plt.tight_layout()
    return fig

# %%
def plot_time_invariant_grid(gcm, flags=None, variables=None):
    flags = flags or FLAG_LIST_TIME_INVARIANT
    variables = variables or VARIABLES
    combos = [c for c in time_invariant_combos if c["gcm"] == gcm and c["flag_name"] in flags]
    present_flags = [f for f in flags if any(c["flag_name"] == f for c in combos)]
    present_vars = [v for v in variables if any(c["variable"] == v for c in combos)]

    fig, axes = plt.subplots(
        nrows=len(present_vars),
        ncols=len(present_flags),
        figsize=(
            PLOT_STYLE["figsize_grid_cell"][0] * len(present_flags),
            PLOT_STYLE["figsize_grid_cell"][1] * len(present_vars),
        ),
        subplot_kw={"projection": ccrs.PlateCarree()},
        squeeze=False,
    )
    for i, var in enumerate(present_vars):
        for j, flag_name in enumerate(present_flags):
            ax = axes[i, j]
            combo = next(
                (c for c in combos if c["variable"] == var and c["flag_name"] == flag_name), None
            )
            if combo is None:
                ax.axis("off")
                continue
            res = time_invariant_results[_ti_combo_key(combo)]
            plot_map(
                res["map"],
                title=f"{var} / {flag_name}",
                ax=ax,
                cmap=PLOT_STYLE["cmap_invariant"],
                vmax=1,
                cbar_label="flagged (0/1)",
            )
    fig.suptitle(f"time-invariant flags ({gcm})", fontsize=PLOT_STYLE["suptitle_fontsize"])
    plt.tight_layout()
    return fig

# %%
def plot_timeseries(flag_name, gcm, var, scenarios=None):
    scenarios = scenarios or SCENARIO_ORDER
    fig, ax = plt.subplots(figsize=(9, 3))
    for scn in scenarios:
        combo = next(
            (
                c
                for c in time_varying_combos
                if c["flag_name"] == flag_name
                and c["gcm"] == gcm
                and c["variable"] == var
                and c["scenario"] == scn
            ),
            None,
        )
        if combo is None:
            continue
        ts = hovmoller_to_timeseries(time_varying_results[_combo_key(combo)]["ensemble_mean_hovmoller"])
        ax.plot(ts["time"], ts, label=scn, linewidth=0.8)
    ax.set_ylabel("area-weighted fraction flagged")
    ax.set_title(f"{flag_name} / {var} ({gcm})", fontsize=PLOT_STYLE["title_fontsize"])
    ax.legend(fontsize=8)
    plt.tight_layout()
    return fig


def plot_boundary_zoom(flag_name, gcm, var, window_days=730):
    """Zoom around the g6_1p5k -> g6_1p5k_end (termination shock) splice."""

    def _find(scn):
        return next(
            (
                c
                for c in time_varying_combos
                if c["flag_name"] == flag_name
                and c["gcm"] == gcm
                and c["variable"] == var
                and c["scenario"] == scn
            ),
            None,
        )

    combo1, combo2 = _find("g6_1p5k"), _find("g6_1p5k_end")
    if combo1 is None or combo2 is None:
        print(f"missing g6_1p5k/g6_1p5k_end data for {flag_name}/{var} ({gcm})")
        return None

    ts1 = hovmoller_to_timeseries(time_varying_results[_combo_key(combo1)]["ensemble_mean_hovmoller"])
    ts2 = hovmoller_to_timeseries(time_varying_results[_combo_key(combo2)]["ensemble_mean_hovmoller"])
    combined = xr.concat([ts1, ts2], dim="time").sortby("time")
    boundary = pd.Timestamp(ts2["time"].values.min())
    window = pd.Timedelta(days=window_days)
    zoomed = combined.sel(time=slice(boundary - window, boundary + window))

    fig, ax = plt.subplots(figsize=(9, 3))
    ax.plot(zoomed["time"], zoomed, linewidth=0.8)
    ax.axvline(boundary, color="k", linestyle="--", linewidth=0.8, label="g6_1p5k -> g6_1p5k_end")
    ax.set_ylabel("area-weighted fraction flagged")
    ax.set_title(f"{flag_name} / {var} ({gcm}) -- scenario splice zoom", fontsize=PLOT_STYLE["title_fontsize"])
    ax.legend(fontsize=8)
    plt.tight_layout()
    return fig


def plot_hovmoller(flag_name, gcm, var, scenario):
    combo = next(
        (
            c
            for c in time_varying_combos
            if c["flag_name"] == flag_name
            and c["gcm"] == gcm
            and c["variable"] == var
            and c["scenario"] == scenario
        ),
        None,
    )
    if combo is None:
        print(f"no data for {flag_name}/{var}/{scenario} ({gcm})")
        return None
    hov = time_varying_results[_combo_key(combo)]["ensemble_mean_hovmoller"]
    fig, ax = plt.subplots(figsize=(9, 4))
    hov.where(hov > 0).plot(ax=ax, x="time", y="lat", cmap=PLOT_STYLE["cmap_hovmoller"])
    ax.set_title(
        f"{flag_name} / {var} / {scenario} ({gcm}) -- Hovmoller (lon-averaged)",
        fontsize=PLOT_STYLE["title_fontsize"],
    )
    plt.tight_layout()
    return fig

# %%
def plot_summary_heatmap(flag_name, gcm, flag_type="time_varying"):
    sub = summary_df[
        (summary_df.flag_name == flag_name) & (summary_df.gcm == gcm) & (summary_df.flag_type == flag_type)
    ]
    pivot = sub.pivot(index="variable", columns="scenario", values="ensemble_mean_frac_flagged")

    fig, ax = plt.subplots(figsize=(1.6 * len(pivot.columns) + 2, 1 + 0.5 * len(pivot.index)))
    im = ax.imshow(pivot.values, cmap=PLOT_STYLE["cmap_map"], aspect="auto")
    ax.set_xticks(range(len(pivot.columns)))
    ax.set_xticklabels(pivot.columns, rotation=45, ha="right")
    ax.set_yticks(range(len(pivot.index)))
    ax.set_yticklabels(pivot.index)
    for i in range(pivot.shape[0]):
        for j in range(pivot.shape[1]):
            val = pivot.values[i, j]
            if not np.isnan(val):
                ax.text(j, i, f"{val:.1e}", ha="center", va="center", fontsize=7)
    plt.colorbar(im, ax=ax, label="ensemble-mean fraction flagged")
    ax.set_title(f"{flag_name} ({gcm})", fontsize=PLOT_STYLE["title_fontsize"])
    plt.tight_layout()
    return fig


def show_top_n(flag_name, gcm, var, scenario, n=15):
    combo = next(
        (
            c
            for c in time_varying_combos
            if c["flag_name"] == flag_name
            and c["gcm"] == gcm
            and c["variable"] == var
            and c["scenario"] == scenario
        ),
        None,
    )
    if combo is None:
        print(f"no data for {flag_name}/{var}/{scenario} ({gcm})")
        return None
    return top_n_pixels(time_varying_results[_combo_key(combo)]["ensemble_mean_map"], n=n)

# %% [markdown]
# ---
# # Quick preview
#
# Compute and plot just **one flag x one variable** (all 4 scenarios, so the time-series /
# boundary-zoom / Hovmoller comparisons still work) plus **one time-invariant flag**, before
# committing to the full ~96-combo run below. Change `PREVIEW_FLAG_NAME` / `PREVIEW_VARIABLE`
# / `PREVIEW_TI_FLAG_NAME` and re-run this section as many times as you like -- every combo
# gets cached in `CACHE_DIR` same as the full run, so nothing computed here is wasted; the
# Full run section's compute loop will just reload these from the cache instead of
# recomputing them.

# %%
# --- Quick preview parameters -----------------------------------------------
PREVIEW_FLAG_NAME = FLAG_LIST_TIME_VARYING[0]
PREVIEW_VARIABLE = VARIABLES[0]
PREVIEW_TI_FLAG_NAME = FLAG_LIST_TIME_INVARIANT[0]
PREVIEW_GCM = GCMS[0]

preview_tv_combos = [
    c
    for c in time_varying_combos
    if c["flag_name"] == PREVIEW_FLAG_NAME and c["gcm"] == PREVIEW_GCM and c["variable"] == PREVIEW_VARIABLE
]
preview_ti_combos = [
    c
    for c in time_invariant_combos
    if c["flag_name"] == PREVIEW_TI_FLAG_NAME and c["gcm"] == PREVIEW_GCM and c["variable"] == PREVIEW_VARIABLE
]
print(
    f"previewing {PREVIEW_FLAG_NAME}/{PREVIEW_VARIABLE}: "
    f"{len(preview_tv_combos)} time-varying combo(s), {len(preview_ti_combos)} time-invariant combo(s)"
)

time_varying_results = {}
for combo in preview_tv_combos:
    key = _combo_key(combo)
    print(key)
    time_varying_results[key] = compute_or_load(key, lambda combo=combo: _compute_time_varying_combo(combo))

time_invariant_results = {}
for combo in preview_ti_combos:
    key = _ti_combo_key(combo)
    print(key)
    time_invariant_results[key] = compute_or_load(key, lambda combo=combo: _compute_time_invariant_combo(combo))
# Out:
# previewing annual_outlier_flag/tas: 4 time-varying combo(s), 0 time-invariant combo(s)
# tv__annual_outlier_flag__CESM2-WACCM__tas__g6_1p5k
# tv__annual_outlier_flag__CESM2-WACCM__tas__g6_1p5k_end
# tv__annual_outlier_flag__CESM2-WACCM__tas__historical
# tv__annual_outlier_flag__CESM2-WACCM__tas__ssp245

# %%
# variables=[PREVIEW_VARIABLE] matters here: the full catalog has every variable for this
# flag, but only PREVIEW_VARIABLE has actually been computed above.
plot_flag_grid(PREVIEW_FLAG_NAME, PREVIEW_GCM, field="ensemble_mean_map", variables=[PREVIEW_VARIABLE])
plt.show()

plot_flag_grid(
    PREVIEW_FLAG_NAME,
    PREVIEW_GCM,
    field="agreement_map",
    variables=[PREVIEW_VARIABLE],
    cmap=PLOT_STYLE["cmap_agreement"],
)
plt.show()

plot_timeseries(PREVIEW_FLAG_NAME, PREVIEW_GCM, PREVIEW_VARIABLE)
plt.show()

plot_boundary_zoom(PREVIEW_FLAG_NAME, PREVIEW_GCM, PREVIEW_VARIABLE)
plt.show()

plot_hovmoller(PREVIEW_FLAG_NAME, PREVIEW_GCM, PREVIEW_VARIABLE, "ssp245")
plt.show()

if preview_ti_combos:
    plot_time_invariant_grid(PREVIEW_GCM, flags=[PREVIEW_TI_FLAG_NAME], variables=[PREVIEW_VARIABLE])
    plt.show()

show_top_n(PREVIEW_FLAG_NAME, PREVIEW_GCM, PREVIEW_VARIABLE, scenario="ssp245", n=10)
# Out:
#      lat     lon     value
# 0  13.25  100.25  0.006443
# 1  13.25  100.50  0.005106
# 2   7.75  123.75  0.004082
# 3  -9.75  -89.00  0.003059
# 4 -10.00  -88.75  0.002930
# 5 -10.00  -89.00  0.002871
# 6  -9.00  -93.25  0.002846
# 7  -9.75  -88.75  0.002831
# 8 -10.00  -88.50  0.002798
# 9  -9.50  -89.50  0.002785

# %% [markdown]
# If these look like the right thing to be evaluating, continue on to **Full run** below.
# If not, change the `PREVIEW_*` variables above and re-run this section -- e.g. try a
# different flag from `FLAG_LIST_TIME_VARYING`/`FLAG_LIST_TIME_INVARIANT`, or a variable more
# likely to show something interesting.

# %% [markdown]
# ---
# # Full run
#
# Computes and plots **one flag at a time**: every `(variable, scenario)` combo for a flag is
# computed first, then that flag's figures (map grid, agreement grid, summary heatmap, time
# series, boundary zoom, Hovmoller) are generated and saved immediately, before moving on to
# the next flag. That way figures for flag 1 are already sitting in `FIGURE_DIR` while flag 2
# is still computing, instead of everything landing only once all ~96 combos are done.
# Anything already cached from the Quick preview above is a fast cache hit here (reloaded
# from `CACHE_DIR`, not recomputed).
#
# Figures are **saved but not displayed inline** -- rendering ~250 images into the notebook's
# own output would make the .ipynb file itself huge. Look at the PNGs in `FIGURE_DIR`
# directly as they land, rather than waiting on this notebook. A progress bar tracks combos
# completed out of the total; it won't move at a constant rate, since `historical` and
# `ssp245` combos (the two long scenarios) take noticeably longer per combo than
# `g6_1p5k_end` -- their `ensemble_mean_hovmoller` array alone is ~10-40x bigger, and it's
# computed in the same `dask.compute()` call as the map for efficiency (see "Helper
# functions" above), making up roughly 90% of everything that ends up in `CACHE_DIR`.
#
# `summary_table.csv` in `CACHE_DIR` is rewritten after every flag too, so it reflects
# whatever's been computed so far, not just the final state once everything finishes.

# %%
time_varying_results = {}
time_invariant_results = {}
summary_rows = []

# %%
print(FLAG_LIST_TIME_VARYING)
# Out:
# ['annual_outlier_flag', 'rsds_max_exceeded', 'outside_global_plausible_range', 'temperature_inconsistency']

# %%
print(FLAG_LIST_TIME_INVARIANT)
# Out:
# ['flipped_sign_ssp245_g6_1p5k', 'flipped_sign_historical_ssp245', 'flipped_sign_historical_g6_1p5k', 'trend_distortion_historical_ssp245', 'trend_distortion_ssp245_g6_1p5k', 'trend_distortion_historical_g6_1p5k', 'flipped_sign_g6_1p5k_g6_1p5k_end', 'trend_distortion_g6_1p5k_g6_1p5k_end']

# %%
for flag_name in FLAG_LIST_TIME_VARYING:
    print(flag_name)
    for gcm in GCMS:
        flag_combos = [c for c in time_varying_combos if c["flag_name"] == flag_name and c["gcm"] == gcm]
        if not flag_combos:
            continue

        for combo in flag_combos:
            print(combo)
            key = _combo_key(combo)
            res = compute_or_load(key, lambda combo=combo: _compute_time_varying_combo(combo))
            time_varying_results[key] = res
            pmt = res["per_member_table"]
            summary_rows.append(
                {
                    "flag_type": "time_varying",
                    "flag_name": combo["flag_name"],
                    "gcm": combo["gcm"],
                    "variable": combo["variable"],
                    "scenario": combo["scenario"],
                    "n_members": len(pmt),
                    "ensemble_mean_frac_flagged": float(pmt["frac_flagged"].mean()),
                    "ensemble_mean_frac_space_ever_flagged": float(pmt["frac_space_ever_flagged"].mean()),
                    "ensemble_mean_frac_flagged_land": float(pmt["frac_flagged_land"].mean()),
                }
            )

        # every (variable, scenario) combo for this flag is computed -- plot and save now,
        # instead of waiting for every other flag to finish too
        summary_df = pd.DataFrame(summary_rows)

        fig = plot_flag_grid(flag_name, gcm, field="ensemble_mean_map")
        fig.savefig(FIGURE_DIR / f"map_{flag_name}_{gcm}.png", dpi=150)
        plt.close(fig)

        fig = plot_flag_grid(flag_name, gcm, field="agreement_map", cmap=PLOT_STYLE["cmap_agreement"])
        fig.savefig(FIGURE_DIR / f"agreement_{flag_name}_{gcm}.png", dpi=150)
        plt.close(fig)

        fig = plot_summary_heatmap(flag_name, gcm)
        fig.savefig(FIGURE_DIR / f"summary_heatmap_{flag_name}_{gcm}.png", dpi=150)
        plt.close(fig)

        for var in VARIABLES:
            fig = plot_timeseries(flag_name, gcm, var)
            fig.savefig(FIGURE_DIR / f"timeseries_{flag_name}_{var}_{gcm}.png", dpi=150)
            plt.close(fig)

            fig = plot_boundary_zoom(flag_name, gcm, var)
            if fig is not None:
                fig.savefig(FIGURE_DIR / f"boundary_zoom_{flag_name}_{var}_{gcm}.png", dpi=150)
                plt.close(fig)

            for scn in SCENARIO_ORDER:
                fig = plot_hovmoller(flag_name, gcm, var, scn)
                if fig is not None:
                    fig.savefig(FIGURE_DIR / f"hovmoller_{flag_name}_{var}_{scn}_{gcm}.png", dpi=150)
                    plt.close(fig)

        summary_df.to_csv(f"{CACHE_DIR}/summary_table.csv", index=False)  # progressively updated
# Out:
# annual_outlier_flag
# {'flag_name': 'annual_outlier_flag', 'gcm': 'CESM2-WACCM', 'variable': 'pr', 'scenario': 'g6_1p5k', 'member_tags': ['CESM2-WACCM_pr_g6_1p5k_001_qdmsd', 'CESM2-WACCM_pr_g6_1p5k_002_qdmsd', 'CESM2-WACCM_pr_g6_1p5k_003_qdmsd']}
# {'flag_name': 'annual_outlier_flag', 'gcm': 'CESM2-WACCM', 'variable': 'pr', 'scenario': 'g6_1p5k_end', 'member_tags': ['CESM2-WACCM_pr_g6_1p5k_end_002_qdmsd']}
# {'flag_name': 'annual_outlier_flag', 'gcm': 'CESM2-WACCM', 'variable': 'pr', 'scenario': 'historical', 'member_tags': ['CESM2-WACCM_pr_historical_r1i1p1f1_qdmsd', 'CESM2-WACCM_pr_historical_r2i1p1f1_qdmsd', 'CESM2-WACCM_pr_historical_r3i1p1f1_qdmsd']}
# {'flag_name': 'annual_outlier_flag', 'gcm': 'CESM2-WACCM', 'variable': 'pr', 'scenario': 'ssp245', 'member_tags': ['CESM2-WACCM_pr_ssp245_001_qdmsd', 'CESM2-WACCM_pr_ssp245_002_qdmsd', 'CESM2-WACCM_pr_ssp245_003_qdmsd', 'CESM2-WACCM_pr_ssp245_004_qdmsd', 'CESM2-WACCM_pr_ssp245_005_qdmsd', 'CESM2-WACCM_pr_ssp245_006_qdmsd', 'CESM2-WACCM_pr_ssp245_007_qdmsd', 'CESM2-WACCM_pr_ssp245_008_qdmsd', 'CESM2-WACCM_pr_ssp245_010_qdmsd', 'CESM2-WACCM_pr_ssp245_009_qdmsd']}
# /opt/coiled/env/lib/python3.13/site-packages/distributed/client.py:3429: UserWarning: Sending large graph of size 15.29 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# /tmp/ipykernel_350048/4191760688.py:25: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'time' ('time',) The recommendation is to set join explicitly for this case.
#   hovmollers = xr.concat([computed[("hovmoller", e)] for e in ens_list], dim=ens_index)
# {'flag_name': 'annual_outlier_flag', 'gcm': 'CESM2-WACCM', 'variable': 'rsds', 'scenario': 'g6_1p5k', 'member_tags': ['CESM2-WACCM_rsds_g6_1p5k_002_qdmsd', 'CESM2-WACCM_rsds_g6_1p5k_001_qdmsd', 'CESM2-WACCM_rsds_g6_1p5k_003_qdmsd']}
# {'flag_name': 'annual_outlier_flag', 'gcm': 'CESM2-WACCM', 'variable': 'rsds', 'scenario': 'g6_1p5k_end', 'member_tags': ['CESM2-WACCM_rsds_g6_1p5k_end_002_qdmsd']}
# {'flag_name': 'annual_outlier_flag', 'gcm': 'CESM2-WACCM', 'variable': 'rsds', 'scenario': 'historical', 'member_tags': ['CESM2-WACCM_rsds_historical_r1i1p1f1_qdmsd', 'CESM2-WACCM_rsds_historical_r2i1p1f1_qdmsd', 'CESM2-WACCM_rsds_historical_r3i1p1f1_qdmsd']}
# {'flag_name': 'annual_outlier_flag', 'gcm': 'CESM2-WACCM', 'variable': 'rsds', 'scenario': 'ssp245', 'member_tags': ['CESM2-WACCM_rsds_ssp245_001_qdmsd', 'CESM2-WACCM_rsds_ssp245_002_qdmsd', 'CESM2-WACCM_rsds_ssp245_003_qdmsd', 'CESM2-WACCM_rsds_ssp245_004_qdmsd', 'CESM2-WACCM_rsds_ssp245_005_qdmsd', 'CESM2-WACCM_rsds_ssp245_006_qdmsd', 'CESM2-WACCM_rsds_ssp245_007_qdmsd', 'CESM2-WACCM_rsds_ssp245_008_qdmsd', 'CESM2-WACCM_rsds_ssp245_009_qdmsd', 'CESM2-WACCM_rsds_ssp245_010_qdmsd']}
# /opt/coiled/env/lib/python3.13/site-packages/distributed/client.py:3429: UserWarning: Sending large graph of size 15.42 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# /tmp/ipykernel_350048/4191760688.py:25: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'time' ('time',) The recommendation is to set join explicitly for this case.
#   hovmollers = xr.concat([computed[("hovmoller", e)] for e in ens_list], dim=ens_index)
# {'flag_name': 'annual_outlier_flag', 'gcm': 'CESM2-WACCM', 'variable': 'tas', 'scenario': 'g6_1p5k', 'member_tags': ['CESM2-WACCM_tas_g6_1p5k_001_qdmsd', 'CESM2-WACCM_tas_g6_1p5k_002_qdmsd', 'CESM2-WACCM_tas_g6_1p5k_003_qdmsd']}
# {'flag_name': 'annual_outlier_flag', 'gcm': 'CESM2-WACCM', 'variable': 'tas', 'scenario': 'g6_1p5k_end', 'member_tags': ['CESM2-WACCM_tas_g6_1p5k_end_002_qdmsd']}
# {'flag_name': 'annual_outlier_flag', 'gcm': 'CESM2-WACCM', 'variable': 'tas', 'scenario': 'historical', 'member_tags': ['CESM2-WACCM_tas_historical_r1i1p1f1_qdmsd', 'CESM2-WACCM_tas_historical_r2i1p1f1_qdmsd', 'CESM2-WACCM_tas_historical_r3i1p1f1_qdmsd']}
# {'flag_name': 'annual_outlier_flag', 'gcm': 'CESM2-WACCM', 'variable': 'tas', 'scenario': 'ssp245', 'member_tags': ['CESM2-WACCM_tas_ssp245_001_qdmsd', 'CESM2-WACCM_tas_ssp245_010_qdmsd', 'CESM2-WACCM_tas_ssp245_003_qdmsd', 'CESM2-WACCM_tas_ssp245_004_qdmsd', 'CESM2-WACCM_tas_ssp245_005_qdmsd', 'CESM2-WACCM_tas_ssp245_006_qdmsd', 'CESM2-WACCM_tas_ssp245_007_qdmsd', 'CESM2-WACCM_tas_ssp245_008_qdmsd', 'CESM2-WACCM_tas_ssp245_009_qdmsd', 'CESM2-WACCM_tas_ssp245_002_qdmsd']}
# {'flag_name': 'annual_outlier_flag', 'gcm': 'CESM2-WACCM', 'variable': 'tasmax', 'scenario': 'g6_1p5k', 'member_tags': ['CESM2-WACCM_tasmax_g6_1p5k_001_qdmsd', 'CESM2-WACCM_tasmax_g6_1p5k_002_qdmsd', 'CESM2-WACCM_tasmax_g6_1p5k_003_qdmsd']}
# {'flag_name': 'annual_outlier_flag', 'gcm': 'CESM2-WACCM', 'variable': 'tasmax', 'scenario': 'g6_1p5k_end', 'member_tags': ['CESM2-WACCM_tasmax_g6_1p5k_end_002_qdmsd']}
# {'flag_name': 'annual_outlier_flag', 'gcm': 'CESM2-WACCM', 'variable': 'tasmax', 'scenario': 'historical', 'member_tags': ['CESM2-WACCM_tasmax_historical_001_qdmsd']}
# {'flag_name': 'annual_outlier_flag', 'gcm': 'CESM2-WACCM', 'variable': 'tasmax', 'scenario': 'ssp245', 'member_tags': ['CESM2-WACCM_tasmax_ssp245_006_qdmsd', 'CESM2-WACCM_tasmax_ssp245_010_qdmsd', 'CESM2-WACCM_tasmax_ssp245_008_qdmsd', 'CESM2-WACCM_tasmax_ssp245_009_qdmsd', 'CESM2-WACCM_tasmax_ssp245_007_qdmsd']}
# {'flag_name': 'annual_outlier_flag', 'gcm': 'CESM2-WACCM', 'variable': 'tasmin', 'scenario': 'g6_1p5k', 'member_tags': ['CESM2-WACCM_tasmin_g6_1p5k_001_qdmsd', 'CESM2-WACCM_tasmin_g6_1p5k_002_qdmsd', 'CESM2-WACCM_tasmin_g6_1p5k_003_qdmsd']}
# {'flag_name': 'annual_outlier_flag', 'gcm': 'CESM2-WACCM', 'variable': 'tasmin', 'scenario': 'g6_1p5k_end', 'member_tags': ['CESM2-WACCM_tasmin_g6_1p5k_end_002_qdmsd']}
# {'flag_name': 'annual_outlier_flag', 'gcm': 'CESM2-WACCM', 'variable': 'tasmin', 'scenario': 'historical', 'member_tags': ['CESM2-WACCM_tasmin_historical_001_qdmsd']}
# {'flag_name': 'annual_outlier_flag', 'gcm': 'CESM2-WACCM', 'variable': 'tasmin', 'scenario': 'ssp245', 'member_tags': ['CESM2-WACCM_tasmin_ssp245_006_qdmsd', 'CESM2-WACCM_tasmin_ssp245_007_qdmsd', 'CESM2-WACCM_tasmin_ssp245_008_qdmsd', 'CESM2-WACCM_tasmin_ssp245_009_qdmsd', 'CESM2-WACCM_tasmin_ssp245_010_qdmsd']}
# /opt/coiled/env/lib/python3.13/site-packages/distributed/client.py:3429: UserWarning: Sending large graph of size 10.32 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# rsds_max_exceeded
# {'flag_name': 'rsds_max_exceeded', 'gcm': 'CESM2-WACCM', 'variable': 'rsds', 'scenario': 'g6_1p5k', 'member_tags': ['CESM2-WACCM_rsds_g6_1p5k_002_qdmsd', 'CESM2-WACCM_rsds_g6_1p5k_001_qdmsd', 'CESM2-WACCM_rsds_g6_1p5k_003_qdmsd']}
# {'flag_name': 'rsds_max_exceeded', 'gcm': 'CESM2-WACCM', 'variable': 'rsds', 'scenario': 'g6_1p5k_end', 'member_tags': ['CESM2-WACCM_rsds_g6_1p5k_end_002_qdmsd']}
# {'flag_name': 'rsds_max_exceeded', 'gcm': 'CESM2-WACCM', 'variable': 'rsds', 'scenario': 'historical', 'member_tags': ['CESM2-WACCM_rsds_historical_r1i1p1f1_qdmsd', 'CESM2-WACCM_rsds_historical_r2i1p1f1_qdmsd', 'CESM2-WACCM_rsds_historical_r3i1p1f1_qdmsd']}
# {'flag_name': 'rsds_max_exceeded', 'gcm': 'CESM2-WACCM', 'variable': 'rsds', 'scenario': 'ssp245', 'member_tags': ['CESM2-WACCM_rsds_ssp245_001_qdmsd', 'CESM2-WACCM_rsds_ssp245_002_qdmsd', 'CESM2-WACCM_rsds_ssp245_003_qdmsd', 'CESM2-WACCM_rsds_ssp245_004_qdmsd', 'CESM2-WACCM_rsds_ssp245_005_qdmsd', 'CESM2-WACCM_rsds_ssp245_006_qdmsd', 'CESM2-WACCM_rsds_ssp245_007_qdmsd', 'CESM2-WACCM_rsds_ssp245_008_qdmsd', 'CESM2-WACCM_rsds_ssp245_009_qdmsd', 'CESM2-WACCM_rsds_ssp245_010_qdmsd']}
# /opt/coiled/env/lib/python3.13/site-packages/distributed/client.py:3429: UserWarning: Sending large graph of size 15.42 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# /tmp/ipykernel_350048/4191760688.py:25: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'time' ('time',) The recommendation is to set join explicitly for this case.
#   hovmollers = xr.concat([computed[("hovmoller", e)] for e in ens_list], dim=ens_index)
# /tmp/ipykernel_350048/4011058653.py:22: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(fontsize=8)
# missing g6_1p5k/g6_1p5k_end data for rsds_max_exceeded/tas (CESM2-WACCM)
# no data for rsds_max_exceeded/tas/historical (CESM2-WACCM)
# no data for rsds_max_exceeded/tas/ssp245 (CESM2-WACCM)
# no data for rsds_max_exceeded/tas/g6_1p5k (CESM2-WACCM)
# no data for rsds_max_exceeded/tas/g6_1p5k_end (CESM2-WACCM)
# missing g6_1p5k/g6_1p5k_end data for rsds_max_exceeded/tasmax (CESM2-WACCM)
# no data for rsds_max_exceeded/tasmax/historical (CESM2-WACCM)
# no data for rsds_max_exceeded/tasmax/ssp245 (CESM2-WACCM)
# no data for rsds_max_exceeded/tasmax/g6_1p5k (CESM2-WACCM)
# no data for rsds_max_exceeded/tasmax/g6_1p5k_end (CESM2-WACCM)
# missing g6_1p5k/g6_1p5k_end data for rsds_max_exceeded/tasmin (CESM2-WACCM)
# no data for rsds_max_exceeded/tasmin/historical (CESM2-WACCM)
# no data for rsds_max_exceeded/tasmin/ssp245 (CESM2-WACCM)
# no data for rsds_max_exceeded/tasmin/g6_1p5k (CESM2-WACCM)
# no data for rsds_max_exceeded/tasmin/g6_1p5k_end (CESM2-WACCM)
# missing g6_1p5k/g6_1p5k_end data for rsds_max_exceeded/pr (CESM2-WACCM)
# no data for rsds_max_exceeded/pr/historical (CESM2-WACCM)
# no data for rsds_max_exceeded/pr/ssp245 (CESM2-WACCM)
# no data for rsds_max_exceeded/pr/g6_1p5k (CESM2-WACCM)
# no data for rsds_max_exceeded/pr/g6_1p5k_end (CESM2-WACCM)
# outside_global_plausible_range
# {'flag_name': 'outside_global_plausible_range', 'gcm': 'CESM2-WACCM', 'variable': 'pr', 'scenario': 'g6_1p5k', 'member_tags': ['CESM2-WACCM_pr_g6_1p5k_001_qdmsd', 'CESM2-WACCM_pr_g6_1p5k_002_qdmsd', 'CESM2-WACCM_pr_g6_1p5k_003_qdmsd']}
# {'flag_name': 'outside_global_plausible_range', 'gcm': 'CESM2-WACCM', 'variable': 'pr', 'scenario': 'g6_1p5k_end', 'member_tags': ['CESM2-WACCM_pr_g6_1p5k_end_002_qdmsd']}
# {'flag_name': 'outside_global_plausible_range', 'gcm': 'CESM2-WACCM', 'variable': 'pr', 'scenario': 'historical', 'member_tags': ['CESM2-WACCM_pr_historical_r1i1p1f1_qdmsd', 'CESM2-WACCM_pr_historical_r2i1p1f1_qdmsd', 'CESM2-WACCM_pr_historical_r3i1p1f1_qdmsd']}
# {'flag_name': 'outside_global_plausible_range', 'gcm': 'CESM2-WACCM', 'variable': 'pr', 'scenario': 'ssp245', 'member_tags': ['CESM2-WACCM_pr_ssp245_001_qdmsd', 'CESM2-WACCM_pr_ssp245_002_qdmsd', 'CESM2-WACCM_pr_ssp245_003_qdmsd', 'CESM2-WACCM_pr_ssp245_004_qdmsd', 'CESM2-WACCM_pr_ssp245_005_qdmsd', 'CESM2-WACCM_pr_ssp245_006_qdmsd', 'CESM2-WACCM_pr_ssp245_007_qdmsd', 'CESM2-WACCM_pr_ssp245_008_qdmsd', 'CESM2-WACCM_pr_ssp245_010_qdmsd', 'CESM2-WACCM_pr_ssp245_009_qdmsd']}
# /opt/coiled/env/lib/python3.13/site-packages/distributed/client.py:3429: UserWarning: Sending large graph of size 15.29 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# /tmp/ipykernel_350048/4191760688.py:25: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'time' ('time',) The recommendation is to set join explicitly for this case.
#   hovmollers = xr.concat([computed[("hovmoller", e)] for e in ens_list], dim=ens_index)
# {'flag_name': 'outside_global_plausible_range', 'gcm': 'CESM2-WACCM', 'variable': 'rsds', 'scenario': 'g6_1p5k', 'member_tags': ['CESM2-WACCM_rsds_g6_1p5k_002_qdmsd', 'CESM2-WACCM_rsds_g6_1p5k_001_qdmsd', 'CESM2-WACCM_rsds_g6_1p5k_003_qdmsd']}
# {'flag_name': 'outside_global_plausible_range', 'gcm': 'CESM2-WACCM', 'variable': 'rsds', 'scenario': 'g6_1p5k_end', 'member_tags': ['CESM2-WACCM_rsds_g6_1p5k_end_002_qdmsd']}
# {'flag_name': 'outside_global_plausible_range', 'gcm': 'CESM2-WACCM', 'variable': 'rsds', 'scenario': 'historical', 'member_tags': ['CESM2-WACCM_rsds_historical_r1i1p1f1_qdmsd', 'CESM2-WACCM_rsds_historical_r2i1p1f1_qdmsd', 'CESM2-WACCM_rsds_historical_r3i1p1f1_qdmsd']}
# {'flag_name': 'outside_global_plausible_range', 'gcm': 'CESM2-WACCM', 'variable': 'rsds', 'scenario': 'ssp245', 'member_tags': ['CESM2-WACCM_rsds_ssp245_001_qdmsd', 'CESM2-WACCM_rsds_ssp245_002_qdmsd', 'CESM2-WACCM_rsds_ssp245_003_qdmsd', 'CESM2-WACCM_rsds_ssp245_004_qdmsd', 'CESM2-WACCM_rsds_ssp245_005_qdmsd', 'CESM2-WACCM_rsds_ssp245_006_qdmsd', 'CESM2-WACCM_rsds_ssp245_007_qdmsd', 'CESM2-WACCM_rsds_ssp245_008_qdmsd', 'CESM2-WACCM_rsds_ssp245_009_qdmsd', 'CESM2-WACCM_rsds_ssp245_010_qdmsd']}
# /opt/coiled/env/lib/python3.13/site-packages/distributed/client.py:3429: UserWarning: Sending large graph of size 15.42 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# /tmp/ipykernel_350048/4191760688.py:25: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'time' ('time',) The recommendation is to set join explicitly for this case.
#   hovmollers = xr.concat([computed[("hovmoller", e)] for e in ens_list], dim=ens_index)
# {'flag_name': 'outside_global_plausible_range', 'gcm': 'CESM2-WACCM', 'variable': 'tas', 'scenario': 'g6_1p5k', 'member_tags': ['CESM2-WACCM_tas_g6_1p5k_001_qdmsd', 'CESM2-WACCM_tas_g6_1p5k_002_qdmsd', 'CESM2-WACCM_tas_g6_1p5k_003_qdmsd']}
# {'flag_name': 'outside_global_plausible_range', 'gcm': 'CESM2-WACCM', 'variable': 'tas', 'scenario': 'g6_1p5k_end', 'member_tags': ['CESM2-WACCM_tas_g6_1p5k_end_002_qdmsd']}
# {'flag_name': 'outside_global_plausible_range', 'gcm': 'CESM2-WACCM', 'variable': 'tas', 'scenario': 'historical', 'member_tags': ['CESM2-WACCM_tas_historical_r1i1p1f1_qdmsd', 'CESM2-WACCM_tas_historical_r2i1p1f1_qdmsd', 'CESM2-WACCM_tas_historical_r3i1p1f1_qdmsd']}
# {'flag_name': 'outside_global_plausible_range', 'gcm': 'CESM2-WACCM', 'variable': 'tas', 'scenario': 'ssp245', 'member_tags': ['CESM2-WACCM_tas_ssp245_001_qdmsd', 'CESM2-WACCM_tas_ssp245_010_qdmsd', 'CESM2-WACCM_tas_ssp245_003_qdmsd', 'CESM2-WACCM_tas_ssp245_004_qdmsd', 'CESM2-WACCM_tas_ssp245_005_qdmsd', 'CESM2-WACCM_tas_ssp245_006_qdmsd', 'CESM2-WACCM_tas_ssp245_007_qdmsd', 'CESM2-WACCM_tas_ssp245_008_qdmsd', 'CESM2-WACCM_tas_ssp245_009_qdmsd', 'CESM2-WACCM_tas_ssp245_002_qdmsd']}
# /opt/coiled/env/lib/python3.13/site-packages/distributed/client.py:3429: UserWarning: Sending large graph of size 15.30 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# /tmp/ipykernel_350048/4191760688.py:25: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'time' ('time',) The recommendation is to set join explicitly for this case.
#   hovmollers = xr.concat([computed[("hovmoller", e)] for e in ens_list], dim=ens_index)
# {'flag_name': 'outside_global_plausible_range', 'gcm': 'CESM2-WACCM', 'variable': 'tasmax', 'scenario': 'g6_1p5k', 'member_tags': ['CESM2-WACCM_tasmax_g6_1p5k_001_qdmsd', 'CESM2-WACCM_tasmax_g6_1p5k_002_qdmsd', 'CESM2-WACCM_tasmax_g6_1p5k_003_qdmsd']}
# {'flag_name': 'outside_global_plausible_range', 'gcm': 'CESM2-WACCM', 'variable': 'tasmax', 'scenario': 'g6_1p5k_end', 'member_tags': ['CESM2-WACCM_tasmax_g6_1p5k_end_002_qdmsd']}
# {'flag_name': 'outside_global_plausible_range', 'gcm': 'CESM2-WACCM', 'variable': 'tasmax', 'scenario': 'historical', 'member_tags': ['CESM2-WACCM_tasmax_historical_001_qdmsd']}
# {'flag_name': 'outside_global_plausible_range', 'gcm': 'CESM2-WACCM', 'variable': 'tasmax', 'scenario': 'ssp245', 'member_tags': ['CESM2-WACCM_tasmax_ssp245_006_qdmsd', 'CESM2-WACCM_tasmax_ssp245_010_qdmsd', 'CESM2-WACCM_tasmax_ssp245_008_qdmsd', 'CESM2-WACCM_tasmax_ssp245_009_qdmsd', 'CESM2-WACCM_tasmax_ssp245_007_qdmsd']}
# {'flag_name': 'outside_global_plausible_range', 'gcm': 'CESM2-WACCM', 'variable': 'tasmin', 'scenario': 'g6_1p5k', 'member_tags': ['CESM2-WACCM_tasmin_g6_1p5k_001_qdmsd', 'CESM2-WACCM_tasmin_g6_1p5k_002_qdmsd', 'CESM2-WACCM_tasmin_g6_1p5k_003_qdmsd']}
# {'flag_name': 'outside_global_plausible_range', 'gcm': 'CESM2-WACCM', 'variable': 'tasmin', 'scenario': 'g6_1p5k_end', 'member_tags': ['CESM2-WACCM_tasmin_g6_1p5k_end_002_qdmsd']}
# {'flag_name': 'outside_global_plausible_range', 'gcm': 'CESM2-WACCM', 'variable': 'tasmin', 'scenario': 'historical', 'member_tags': ['CESM2-WACCM_tasmin_historical_001_qdmsd']}
# {'flag_name': 'outside_global_plausible_range', 'gcm': 'CESM2-WACCM', 'variable': 'tasmin', 'scenario': 'ssp245', 'member_tags': ['CESM2-WACCM_tasmin_ssp245_006_qdmsd', 'CESM2-WACCM_tasmin_ssp245_007_qdmsd', 'CESM2-WACCM_tasmin_ssp245_008_qdmsd', 'CESM2-WACCM_tasmin_ssp245_009_qdmsd', 'CESM2-WACCM_tasmin_ssp245_010_qdmsd']}
# /opt/coiled/env/lib/python3.13/site-packages/distributed/client.py:3429: UserWarning: Sending large graph of size 10.32 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# temperature_inconsistency
# {'flag_name': 'temperature_inconsistency', 'gcm': 'CESM2-WACCM', 'variable': 'tas', 'scenario': 'g6_1p5k', 'member_tags': ['CESM2-WACCM_tas_g6_1p5k_001_qdmsd', 'CESM2-WACCM_tas_g6_1p5k_002_qdmsd', 'CESM2-WACCM_tas_g6_1p5k_003_qdmsd']}
# {'flag_name': 'temperature_inconsistency', 'gcm': 'CESM2-WACCM', 'variable': 'tas', 'scenario': 'g6_1p5k_end', 'member_tags': ['CESM2-WACCM_tas_g6_1p5k_end_002_qdmsd']}
# {'flag_name': 'temperature_inconsistency', 'gcm': 'CESM2-WACCM', 'variable': 'tas', 'scenario': 'ssp245', 'member_tags': ['CESM2-WACCM_tas_ssp245_010_qdmsd', 'CESM2-WACCM_tas_ssp245_006_qdmsd', 'CESM2-WACCM_tas_ssp245_007_qdmsd', 'CESM2-WACCM_tas_ssp245_008_qdmsd', 'CESM2-WACCM_tas_ssp245_009_qdmsd']}
# /opt/coiled/env/lib/python3.13/site-packages/distributed/client.py:3429: UserWarning: Sending large graph of size 10.32 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# no data for temperature_inconsistency/tas/historical (CESM2-WACCM)
# /tmp/ipykernel_350048/4011058653.py:22: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(fontsize=8)
# missing g6_1p5k/g6_1p5k_end data for temperature_inconsistency/tasmax (CESM2-WACCM)
# no data for temperature_inconsistency/tasmax/historical (CESM2-WACCM)
# no data for temperature_inconsistency/tasmax/ssp245 (CESM2-WACCM)
# no data for temperature_inconsistency/tasmax/g6_1p5k (CESM2-WACCM)
# no data for temperature_inconsistency/tasmax/g6_1p5k_end (CESM2-WACCM)
# missing g6_1p5k/g6_1p5k_end data for temperature_inconsistency/tasmin (CESM2-WACCM)
# no data for temperature_inconsistency/tasmin/historical (CESM2-WACCM)
# no data for temperature_inconsistency/tasmin/ssp245 (CESM2-WACCM)
# no data for temperature_inconsistency/tasmin/g6_1p5k (CESM2-WACCM)
# no data for temperature_inconsistency/tasmin/g6_1p5k_end (CESM2-WACCM)
# missing g6_1p5k/g6_1p5k_end data for temperature_inconsistency/pr (CESM2-WACCM)
# no data for temperature_inconsistency/pr/historical (CESM2-WACCM)
# no data for temperature_inconsistency/pr/ssp245 (CESM2-WACCM)
# no data for temperature_inconsistency/pr/g6_1p5k (CESM2-WACCM)
# no data for temperature_inconsistency/pr/g6_1p5k_end (CESM2-WACCM)
# missing g6_1p5k/g6_1p5k_end data for temperature_inconsistency/rsds (CESM2-WACCM)
# no data for temperature_inconsistency/rsds/historical (CESM2-WACCM)
# no data for temperature_inconsistency/rsds/ssp245 (CESM2-WACCM)
# no data for temperature_inconsistency/rsds/g6_1p5k (CESM2-WACCM)
# no data for temperature_inconsistency/rsds/g6_1p5k_end (CESM2-WACCM)

# %%
for flag_name in FLAG_LIST_TIME_INVARIANT:
    for gcm in GCMS:
        flag_combos = [c for c in time_invariant_combos if c["flag_name"] == flag_name and c["gcm"] == gcm]
        if not flag_combos:
            continue

        for combo in flag_combos:
            key = _ti_combo_key(combo)
            res = compute_or_load(key, lambda combo=combo: _compute_time_invariant_combo(combo))
            time_invariant_results[key] = res
            summary_rows.append(
                {
                    "flag_type": "time_invariant",
                    "flag_name": combo["flag_name"],
                    "gcm": combo["gcm"],
                    "variable": combo["variable"],
                    "scenario": None,
                    "n_members": None,
                    "ensemble_mean_frac_flagged": res["frac_flagged"],
                    "ensemble_mean_frac_space_ever_flagged": None,
                    "ensemble_mean_frac_flagged_land": res["frac_flagged_land"],
                }
            )

        summary_df = pd.DataFrame(summary_rows)
        fig = plot_time_invariant_grid(gcm, flags=[flag_name])
        fig.savefig(FIGURE_DIR / f"time_invariant_map_{flag_name}_{gcm}.png", dpi=150)
        plt.close(fig)
        summary_df.to_csv(f"{CACHE_DIR}/summary_table.csv", index=False)

summary_df  # final, complete summary table
# Out:
#          flag_type                             flag_name          gcm  \
# 0     time_varying                   annual_outlier_flag  CESM2-WACCM
# 1     time_varying                   annual_outlier_flag  CESM2-WACCM
# 2     time_varying                   annual_outlier_flag  CESM2-WACCM
# 3     time_varying                   annual_outlier_flag  CESM2-WACCM
# 4     time_varying                   annual_outlier_flag  CESM2-WACCM
# ..             ...                                   ...          ...
# 66  time_invariant  trend_distortion_g6_1p5k_g6_1p5k_end  CESM2-WACCM
# 67  time_invariant  trend_distortion_g6_1p5k_g6_1p5k_end  CESM2-WACCM
# 68  time_invariant  trend_distortion_g6_1p5k_g6_1p5k_end  CESM2-WACCM
# 69  time_invariant  trend_distortion_g6_1p5k_g6_1p5k_end  CESM2-WACCM
# 70  time_invariant  trend_distortion_g6_1p5k_g6_1p5k_end  CESM2-WACCM
#
#    variable     scenario  n_members  ensemble_mean_frac_flagged  \
# 0        pr      g6_1p5k        3.0                1.509982e-06
# 1        pr  g6_1p5k_end        1.0                1.436758e-06
# 2        pr   historical        3.0                3.782162e-08
# 3        pr       ssp245       10.0                1.924706e-06
# 4      rsds      g6_1p5k        3.0                5.505964e-06
# ..      ...          ...        ...                         ...
# 66       pr          NaN        NaN                3.767934e-01
# 67     rsds          NaN        NaN                3.035368e-01
# 68      tas          NaN        NaN                4.997785e-02
# 69   tasmax          NaN        NaN                4.402643e-03
# 70   tasmin          NaN        NaN                4.546348e-02
#
#     ensemble_mean_frac_space_ever_flagged  ensemble_mean_frac_flagged_land
# 0                                0.020476                     6.484459e-07
# 1                                0.007316                     1.119616e-06
# 2                                0.000226                     1.113284e-07
# 3                                0.035390                     9.604966e-07
# 4                                0.001943                     1.023688e-05
# ..                                    ...                              ...
# 66                                    NaN                     5.002807e-01
# 67                                    NaN                     3.107373e-01
# 68                                    NaN                     4.775823e-02
# 69                                    NaN                     5.516467e-03
# 70                                    NaN                     2.009356e-02
#
# [71 rows x 9 columns]

# %% [markdown]
# ## Top-N worst-offender pixels (example)
#
# Cheap lookups from the already-cached ensemble-mean maps -- adjust the flag/variable/
# scenario/`n` below for whichever cell in the grid figures above looks worth drilling
# into.

# %%
show_top_n(flag_name=FLAG_LIST_TIME_VARYING[0], gcm=GCMS[0], var=VARIABLES[0], scenario="ssp245", n=15)
# Out:
#       lat     lon     value
# 0   13.25  100.25  0.006443
# 1   13.25  100.50  0.005106
# 2    7.75  123.75  0.004082
# 3   -9.75  -89.00  0.003059
# 4  -10.00  -88.75  0.002930
# 5  -10.00  -89.00  0.002871
# 6   -9.00  -93.25  0.002846
# 7   -9.75  -88.75  0.002831
# 8  -10.00  -88.50  0.002798
# 9   -9.50  -89.50  0.002785
# 10  -8.75  -93.25  0.002768
# 11  -9.75  -89.25  0.002756
# 12  -9.50  -89.25  0.002751
# 13  -9.00  -93.50  0.002670
# 14 -10.25  -88.75  0.002611

# %% [markdown]
# ## Shut down the cluster

# %%
client.close()
cluster.close()
